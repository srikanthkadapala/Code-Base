# %%
import findspark
findspark.init()
findspark.find()
import pyspark
import datetime as dt
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
conf = pyspark.SparkConf().setAppName("appName").setMaster("local")
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession(sc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-9f1a93566211> in <module>
# ----> 1 import findspark
#       2 findspark.init()
#       3 findspark.find()
#       4 import pyspark
#       5 import datetime as dt
#
# ModuleNotFoundError: No module named 'findspark'

# %%
x=sc.textFile("hdfs://172.16.1.114:8020/user/hive/warehouse/workingDirectory/500000_Records.csv")

# %%
def Func(lines):
    lines = lines.lower()
    lines = lines.split(',')
    return lines

# %%
rdd1 = x.map(Func)
rdd1.take(2)
# Out:
# [['emp id',
#   'name prefix',
#   'first name',
#   'middle initial',
#   'last name',
#   'gender',
#   'e mail',
#   "father's name",
#   "mother's name",
#   "mother's maiden name",
#   'date of birth',
#   'time of birth',
#   'age in yrs.',
#   'weight in kgs.',
#   'date of joining',
#   'quarter of joining',
#   'half of joining',
#   'year of joining',
#   'month of joining',
#   'month name of joining',
#   'short month',
#   'day of joining',
#   'dow of joining',
#   'short dow',
#   'age in company (years)',
#   'salary',
#   'last % hike',
#   'ssn',
#   'phone no. ',
#   'place name',
#   'county',
#   'city',
#   'state',
#   'zip',
#   'region',
#   'user name',
#   'password'],
#  ['857211',
#   'ms.',
#   'hermila',
#   'j',
#   'suhr',
#   'f',
#   'hermila.suhr@gmail.com',
#   'todd suhr',
#   'cathrine suhr',
#   'hinojosa',
#   '9/4/1992',
#   '04:29:56 am',
#   '24.91',
#   '57',
#   '9/9/2014',
#   'q3',
#   'h2',
#   '2014',
#   '9',
#   'september',
#   'sep',
#   '9',
#   'tuesday',
#   'tue',
#   '2.88',
#   '168991',
#   '12%',
#   '275-17-8844',
#   '479-539-4593',
#   'peach orchard',
#   'clay',
#   'peach orchard',
#   'ar',
#   '72453',
#   'south',
#   'hjsuhr',
#   'oz%{<6wn!a']]

# %%
rdd2 = x.flatMap(Func)
rdd2.take(10)
# Out:
# ['emp id',
#  'name prefix',
#  'first name',
#  'middle initial',
#  'last name',
#  'gender',
#  'e mail',
#  "father's name",
#  "mother's name",
#  "mother's maiden name"]

# %%
s=x.map(lambda x:x.split(','))
s.take(2)
# Out:
# [['Emp ID',
#   'Name Prefix',
#   'First Name',
#   'Middle Initial',
#   'Last Name',
#   'Gender',
#   'E Mail',
#   "Father's Name",
#   "Mother's Name",
#   "Mother's Maiden Name",
#   'Date of Birth',
#   'Time of Birth',
#   'Age in Yrs.',
#   'Weight in Kgs.',
#   'Date of Joining',
#   'Quarter of Joining',
#   'Half of Joining',
#   'Year of Joining',
#   'Month of Joining',
#   'Month Name of Joining',
#   'Short Month',
#   'Day of Joining',
#   'DOW of Joining',
#   'Short DOW',
#   'Age in Company (Years)',
#   'Salary',
#   'Last % Hike',
#   'SSN',
#   'Phone No. ',
#   'Place Name',
#   'County',
#   'City',
#   'State',
#   'Zip',
#   'Region',
#   'User Name',
#   'Password'],
#  ['857211',
#   'Ms.',
#   'Hermila',
#   'J',
#   'Suhr',
#   'F',
#   'hermila.suhr@gmail.com',
#   'Todd Suhr',
#   'Cathrine Suhr',
#   'Hinojosa',
#   '9/4/1992',
#   '04:29:56 AM',
#   '24.91',
#   '57',
#   '9/9/2014',
#   'Q3',
#   'H2',
#   '2014',
#   '9',
#   'September',
#   'Sep',
#   '9',
#   'Tuesday',
#   'Tue',
#   '2.88',
#   '168991',
#   '12%',
#   '275-17-8844',
#   '479-539-4593',
#   'Peach Orchard',
#   'Clay',
#   'Peach Orchard',
#   'AR',
#   '72453',
#   'South',
#   'hjsuhr',
#   'oZ%{<6wN!A']]

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
s=x.map(lambda x:x.split(','))

# %%
s.collect()
# Out:
# [['id',
#   'airport_ident',
#   'type',
#   'name',
#   'latitude_deg',
#   'longitude_deg',
#   'elevation_ft',
#   'continent',
#   'iso_country',
#   'iso_region',
#   'municipality',
#   'scheduled_service',
#   'gps_code',
#   'iata_code',
#   'local_code',
#   'home_link',
#   'wikipedia_link',
#   'keywords'],
#  ['6523',
#   '00A',
#   'heliport',
#   'Total Rf Heliport',
#   '40.07080078',
#   '-74.93360138',
#   '112233',
#   'NA',
#   'US',
#   'US-PA',
#   'Bensalem',
#   'no',
#   '00A',
#   '',
#   '00A',
#   '',
#   '',
#   ''],
#  ['323361',
#   '00AA',
#   'small_airport',
#   'Aero B Ranch Airport',
#   '38.704022',
#   '-101.473911',
#   '3435',
#   'NA',
#   'US',
#   'US-KS',
#   'Leoti',
#   'no',
#   '00AA',
#   '',
#   '00AA',
#   '',
#   '',
#   ''],
#  ['6524',
#   '00AK',
#   'small_airport',
#   'Lowell Field',
#   '59.94919968',
#   '-151.6959991',
#   '450',
#   'NA',
#   'US',
#   'US-AK',
#   'Anchor Point',
#   'no',
#   '00AK',
#   '',
#   '00AK',
#   '',
#   '',
#   ''],
#  ['6525',
#   '00AL',
#   'small_airport',
#   'Epps Airpark',
#   '34.8647995',
#   '-86.77030182',
#   '820',
#   'NA',
#   'US',
#   'US-AL',
#   'Harvest',
#   'no',
#   '00AL',
#   '',
#   '00AL',
#   '',
#   '',
#   ''],
#  ['6526',
#   '00AR',
#   'closed',
#   'Newport Hospital & Clinic Heliport',
#   '35.6087',
#   '-91.254898',
#   '237',
#   'NA',
#   'US',
#   'US-AR',
#   'Newport',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '00AR'],
#  ['322127',
#   '00AS',
#   'small_airport',
#   'Fulton Airport',
#   '34.9428028',
#   '-97.8180194',
#   '1100',
#   'NA',
#   'US',
#   'US-OK',
#   'Alex',
#   'no',
#   '00AS',
#   '',
#   '00AS',
#   '',
#   '',
#   ''],
#  ['6527',
#   '00AZ',
#   'small_airport',
#   'Cordes Airport',
#   '34.30559921',
#   '-112.1650009',
#   '3810',
#   'NA',
#   'US',
#   'US-AZ',
#   'Cordes',
#   'no',
#   '00AZ',
#   '',
#   '00AZ',
#   '',
#   '',
#   ''],
#  ['6528',
#   '00CA',
#   'small_airport',
#   'Goldstone /Gts/ Airport',
#   '35.3504982',
#   '-116.8880005',
#   '3038',
#   'NA',
#   'US',
#   'US-CA',
#   'Barstow',
#   'no',
#   '00CA',
#   '',
#   '00CA',
#   '',
#   '',
#   ''],
#  ['324424',
#   '00CL',
#   'small_airport',
#   'Williams Ag Airport',
#   '39.427188',
#   '-121.763427',
#   '87',
#   'NA',
#   'US',
#   'US-CA',
#   'Biggs',
#   'no',
#   '00CL',
#   '',
#   '00CL',
#   '',
#   '',
#   ''],
#  ['322658',
#   '00CN',
#   'heliport',
#   'Kitchen Creek Helibase Heliport',
#   '32.7273736',
#   '-116.4597417',
#   '3350',
#   'NA',
#   'US',
#   'US-CA',
#   'Pine Valley',
#   'no',
#   '00CN',
#   '',
#   '00CN',
#   '',
#   '',
#   ''],
#  ['6529',
#   '00CO',
#   'closed',
#   'Cass Field',
#   '40.622202',
#   '-104.344002',
#   '4830',
#   'NA',
#   'US',
#   'US-CO',
#   'Briggsdale',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '00CO'],
#  ['6531',
#   '00FA',
#   'small_airport',
#   'Grass Patch Airport',
#   '28.64550018',
#   '-82.21900177',
#   '53',
#   'NA',
#   'US',
#   'US-FL',
#   'Bushnell',
#   'no',
#   '00FA',
#   '',
#   '00FA',
#   '',
#   '',
#   ''],
#  ['6532',
#   '00FD',
#   'heliport',
#   'Ringhaver Heliport',
#   '28.84659958',
#   '-82.34539795',
#   '25',
#   'NA',
#   'US',
#   'US-FL',
#   'Riverview',
#   'no',
#   '00FD',
#   '',
#   '00FD',
#   '',
#   '',
#   ''],
#  ['6533',
#   '00FL',
#   'small_airport',
#   'River Oak Airport',
#   '27.23089981',
#   '-80.96920013',
#   '35',
#   'NA',
#   'US',
#   'US-FL',
#   'Okeechobee',
#   'no',
#   '00FL',
#   '',
#   '00FL',
#   '',
#   '',
#   ''],
#  ['6534',
#   '00GA',
#   'small_airport',
#   'Lt World Airport',
#   '33.76750183',
#   '-84.06829834',
#   '700',
#   'NA',
#   'US',
#   'US-GA',
#   'Lithonia',
#   'no',
#   '00GA',
#   '',
#   '00GA',
#   '',
#   '',
#   ''],
#  ['6535',
#   '00GE',
#   'heliport',
#   'Caffrey Heliport',
#   '33.88420105',
#   '-84.73390198',
#   '957',
#   'NA',
#   'US',
#   'US-GA',
#   'Hiram',
#   'no',
#   '00GE',
#   '',
#   '00GE',
#   '',
#   '',
#   ''],
#  ['6536',
#   '00HI',
#   'heliport',
#   'Kaupulehu Heliport',
#   '19.832715',
#   '-155.980233',
#   '43',
#   'NA',
#   'US',
#   'US-HI',
#   'Kailua/Kona',
#   'no',
#   '00HI',
#   '',
#   '00HI',
#   '',
#   '',
#   ''],
#  ['6537',
#   '00ID',
#   'small_airport',
#   'Delta Shores Airport',
#   '48.14530182',
#   '-116.2139969',
#   '2064',
#   'NA',
#   'US',
#   'US-ID',
#   'Clark Fork',
#   'no',
#   '00ID',
#   '',
#   '00ID',
#   '',
#   '',
#   ''],
#  ['322581',
#   '00IG',
#   'small_airport',
#   'Goltl Airport',
#   '39.724028',
#   '-101.395994',
#   '3359',
#   'NA',
#   'US',
#   'US-KS',
#   'McDonald',
#   'no',
#   '00IG',
#   '',
#   '00IG',
#   '',
#   '',
#   ''],
#  ['6538',
#   '00II',
#   'heliport',
#   'Bailey Generation Station Heliport',
#   '41.64450073',
#   '-87.12280273',
#   '600',
#   'NA',
#   'US',
#   'US-IN',
#   'Chesterton',
#   'no',
#   '00II',
#   '',
#   '00II',
#   '',
#   '',
#   ''],
#  ['6539',
#   '00IL',
#   'small_airport',
#   'Hammer Airport',
#   '41.97840118',
#   '-89.56040192',
#   '840',
#   'NA',
#   'US',
#   'US-IL',
#   'Polo',
#   'no',
#   '00IL',
#   '',
#   '00IL',
#   '',
#   '',
#   ''],
#  ['6540',
#   '00IN',
#   'heliport',
#   'St Mary Medical Center Heliport',
#   '41.51139832',
#   '-87.26059723',
#   '634',
#   'NA',
#   'US',
#   'US-IN',
#   'Hobart',
#   'no',
#   '00IN',
#   '',
#   '00IN',
#   '',
#   '',
#   ''],
#  ['6541',
#   '00IS',
#   'small_airport',
#   "Hayenga's Cant Find Farms Airport",
#   '40.02560043',
#   '-89.12290192',
#   '820',
#   'NA',
#   'US',
#   'US-IL',
#   'Kings',
#   'no',
#   '00IS',
#   '',
#   '00IS',
#   '',
#   '',
#   ''],
#  ['6542',
#   '00KS',
#   'small_airport',
#   'Hayden Farm Airport',
#   '38.72779846',
#   '-94.93049622',
#   '1100',
#   'NA',
#   'US',
#   'US-KS',
#   'Gardner',
#   'no',
#   '00KS',
#   '',
#   '00KS',
#   '',
#   '',
#   ''],
#  ['6543',
#   '00KY',
#   'small_airport',
#   'Robbins Roost Airport',
#   '37.40940094',
#   '-84.61969757',
#   '1265',
#   'NA',
#   'US',
#   'US-KY',
#   'Stanford',
#   'no',
#   '00KY',
#   '',
#   '00KY',
#   '',
#   '',
#   ''],
#  ['45437',
#   '00LA',
#   'heliport',
#   'Shell Chemical East Site Heliport',
#   '30.191944',
#   '-90.980833',
#   '15',
#   'NA',
#   'US',
#   'US-LA',
#   'Gonzales',
#   'no',
#   '00LA',
#   '',
#   '00LA',
#   '',
#   '',
#   ''],
#  ['6544',
#   '00LL',
#   'heliport',
#   'Ac & R Components Heliport',
#   '39.66529846',
#   '-89.70559692',
#   '600',
#   'NA',
#   'US',
#   'US-IL',
#   'Chatham',
#   'no',
#   '00LL',
#   '',
#   '00LL',
#   '',
#   '',
#   ''],
#  ['6545',
#   '00LS',
#   'small_airport',
#   'Lejeune Airport',
#   '30.13629913',
#   '-92.42939758',
#   '12',
#   'NA',
#   'US',
#   'US-LA',
#   'Esterwood',
#   'no',
#   '00LS',
#   '',
#   '00LS',
#   '',
#   '',
#   ''],
#  ['6546',
#   '00MD',
#   'small_airport',
#   'Slater Field',
#   '38.75709915',
#   '-75.75379944',
#   '45',
#   'NA',
#   'US',
#   'US-MD',
#   'Federalsburg',
#   'no',
#   '00MD',
#   '',
#   '00MD',
#   '',
#   '',
#   ''],
#  ['6547',
#   '00MI',
#   'heliport',
#   'Dow Chemical Heliport',
#   '43.94940186',
#   '-86.41670227',
#   '588',
#   'NA',
#   'US',
#   'US-MI',
#   'Ludington',
#   'no',
#   '00MI',
#   '',
#   '00MI',
#   '',
#   '',
#   ''],
#  ['6548',
#   '00MN',
#   'small_airport',
#   'Battle Lake Municipal Airport',
#   '46.29999924',
#   '-95.70030212',
#   '1365',
#   'NA',
#   'US',
#   'US-MN',
#   'Battle Lake',
#   'no',
#   '00MN',
#   '',
#   '00MN',
#   '',
#   '',
#   ''],
#  ['6549',
#   '00MO',
#   'small_airport',
#   'Cooper Flying Service Airport',
#   '37.20280075',
#   '-94.41239929',
#   '970',
#   'NA',
#   'US',
#   'US-MO',
#   'Alba',
#   'no',
#   '00MO',
#   '',
#   '00MO',
#   '',
#   '',
#   '5K8'],
#  ['6550',
#   '00MT',
#   'closed',
#   'Sands Ranch Airport',
#   '48.537498',
#   '-109.705002',
#   '2600',
#   'NA',
#   'US',
#   'US-MT',
#   'Havre',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '00MT'],
#  ['6551',
#   '00N',
#   'small_airport',
#   'Bucks Airport',
#   '39.47320175',
#   '-75.18520355',
#   '105',
#   'NA',
#   'US',
#   'US-NJ',
#   'Bridgeton',
#   'no',
#   '00N',
#   '',
#   '00N',
#   '',
#   '',
#   ''],
#  ['6552',
#   '00NC',
#   'small_airport',
#   'North Raleigh Airport',
#   '36.08520126',
#   '-78.37139893',
#   '348',
#   'NA',
#   'US',
#   'US-NC',
#   'Louisburg',
#   'no',
#   '00NC',
#   '',
#   '00NC',
#   '',
#   '',
#   ''],
#  ['6553',
#   '00NJ',
#   'heliport',
#   'Colgate-Piscataway Heliport',
#   '40.52090073',
#   '-74.47460175',
#   '78',
#   'NA',
#   'US',
#   'US-NJ',
#   'New Brunswick',
#   'no',
#   '00NJ',
#   '',
#   '00NJ',
#   '',
#   '',
#   ''],
#  ['321919',
#   '00NK',
#   'seaplane_base',
#   'Cliche Cove Seaplane Base',
#   '44.8118612',
#   '-73.3698057',
#   '96',
#   'NA',
#   'US',
#   'US-NY',
#   'Beekmantown',
#   'no',
#   '00NK',
#   '',
#   '00NK',
#   '',
#   '',
#   ''],
#  ['6554',
#   '00NY',
#   'small_airport',
#   'Weiss Airfield',
#   '42.90010071',
#   '-77.49970245',
#   '1000',
#   'NA',
#   'US',
#   'US-NY',
#   'West Bloomfield',
#   'no',
#   '00NY',
#   '',
#   '00NY',
#   '',
#   '',
#   ''],
#  ['6555',
#   '00OH',
#   'small_airport',
#   'Exit 3 Airport',
#   '41.59090042',
#   '-84.14219666',
#   '785',
#   'NA',
#   'US',
#   'US-OH',
#   'Wauseon',
#   'no',
#   '00OH',
#   '',
#   '00OH',
#   '',
#   '',
#   ''],
#  ['6556',
#   '00OI',
#   'heliport',
#   'Miami Valley Hospital Heliport',
#   '39.74530029',
#   '-84.18740082',
#   '905',
#   'NA',
#   'US',
#   'US-OH',
#   'Dayton',
#   'no',
#   '00OI',
#   '',
#   '00OI',
#   '',
#   '',
#   ''],
#  ['328503',
#   '00OK',
#   'small_airport',
#   'Gull Bay Landing Airport',
#   '36.198598',
#   '-96.217693',
#   '960',
#   'NA',
#   'US',
#   'US-OK',
#   'Sandsprings',
#   'no',
#   '00OK',
#   '',
#   '00OK',
#   '',
#   '',
#   ''],
#  ['6557',
#   '00OR',
#   'heliport',
#   'Steel Systems Heliport',
#   '44.93289948',
#   '-123.1299973',
#   '195',
#   'NA',
#   'US',
#   'US-OR',
#   'Salem',
#   'no',
#   '00OR',
#   '',
#   '00OR',
#   '',
#   '',
#   ''],
#  ['6558',
#   '00PA',
#   'heliport',
#   'R J D Heliport',
#   '39.94889832',
#   '-75.74690247',
#   '402',
#   'NA',
#   'US',
#   'US-PA',
#   'Coatesville',
#   'no',
#   '00PA',
#   '',
#   '00PA',
#   '',
#   '',
#   ''],
#  ['45773',
#   '00PN',
#   'small_airport',
#   'Ferrell Field',
#   '41.2995',
#   '-80.211111',
#   '1301',
#   'NA',
#   'US',
#   'US-PA',
#   'Mercer',
#   'no',
#   '00PN',
#   '',
#   '00PN',
#   '',
#   '',
#   ''],
#  ['6559',
#   '00PS',
#   'closed',
#   'Thomas Field',
#   '40.3778',
#   '-77.365303',
#   '815',
#   'NA',
#   'US',
#   'US-PA',
#   'Loysville',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '00PS'],
#  ['6560',
#   '00S',
#   'small_airport',
#   'Mc Kenzie Bridge State Airport',
#   '44.18320084',
#   '-122.0889969',
#   '1620',
#   'NA',
#   'US',
#   'US-OR',
#   'Mc Kenzie Bridge',
#   'no',
#   '00S',
#   '',
#   '00S',
#   '',
#   'http://en.wikipedia.org/wiki/McKenzie_Bridge_State_Airport',
#   ''],
#  ['6561',
#   '00SC',
#   'small_airport',
#   'Flying O Airport',
#   '34.00939941',
#   '-80.26719666',
#   '150',
#   'NA',
#   'US',
#   'US-SC',
#   'Sumter',
#   'no',
#   '00SC',
#   '',
#   '00SC',
#   '',
#   '',
#   ''],
#  ['330391',
#   '00SD',
#   'small_airport',
#   'Homan Field',
#   '44.809158',
#   '-96.498897',
#   '1590',
#   'NA',
#   'US',
#   'US-SD',
#   'Gary',
#   'no',
#   '00SD',
#   '',
#   '00SD',
#   '',
#   '',
#   ''],
#  ['6562',
#   '00TA',
#   'heliport',
#   'Sw Region Faa Heliport',
#   '32.82690048',
#   '-97.30580139',
#   '598',
#   'NA',
#   'US',
#   'US-TX',
#   'Fort Worth',
#   'no',
#   '00TA',
#   '',
#   '00TA',
#   '',
#   '',
#   ''],
#  ['6563',
#   '00TE',
#   'heliport',
#   'Tcjc-Northeast Campus Heliport',
#   '32.84759903',
#   '-97.1894989',
#   '600',
#   'NA',
#   'US',
#   'US-TX',
#   'Fort Worth',
#   'no',
#   '00TE',
#   '',
#   '00TE',
#   '',
#   '',
#   ''],
#  ['6564',
#   '00TN',
#   'small_airport',
#   'Ragsdale Road Airport',
#   '35.51589966',
#   '-85.95359802',
#   '1100',
#   'NA',
#   'US',
#   'US-TN',
#   'Manchester',
#   'no',
#   '00TN',
#   '',
#   '00TN',
#   '',
#   '',
#   ''],
#  ['6565',
#   '00TS',
#   'small_airport',
#   'Alpine Range Airport',
#   '32.60760117',
#   '-97.24199677',
#   '670',
#   'NA',
#   'US',
#   'US-TX',
#   'Everman',
#   'no',
#   '00TS',
#   '',
#   '00TS',
#   '',
#   '',
#   ''],
#  ['6566',
#   '00TX',
#   'closed',
#   'San Jacinto Methodist Hospital Heliport',
#   '29.7377',
#   '-94.980201',
#   '19',
#   'NA',
#   'US',
#   'US-TX',
#   'Baytown',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '00TX'],
#  ['6567',
#   '00UT',
#   'closed',
#   'Clear Creek Ranch Airport',
#   '37.247799',
#   '-112.821998',
#   '6138',
#   'NA',
#   'US',
#   'US-UT',
#   'Kanab',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '"00UT',
#   ' U21"'],
#  ['6568',
#   '00VA',
#   'small_airport',
#   'Vaughan Airport',
#   '36.57600021',
#   '-78.9991684',
#   '551',
#   'NA',
#   'US',
#   'US-VA',
#   'Alton',
#   'no',
#   '00VA',
#   '',
#   '00VA',
#   '',
#   '',
#   ''],
#  ['6569',
#   '00VI',
#   'small_airport',
#   'Groundhog Mountain Airport',
#   '36.66329956',
#   '-80.49949646',
#   '2680',
#   'NA',
#   'US',
#   'US-VA',
#   'Hillsville',
#   'no',
#   '00VI',
#   '',
#   '00VI',
#   '',
#   '',
#   ''],
#  ['6570',
#   '00W',
#   'small_airport',
#   'Lower Granite State Airport',
#   '46.67350006',
#   '-117.4430008',
#   '719',
#   'NA',
#   'US',
#   'US-WA',
#   'Colfax',
#   'no',
#   '00W',
#   '',
#   '00W',
#   'http://www.wsdot.wa.gov/aviation/AllStateAirports/Colfax_LowerGraniteState.htm',
#   '',
#   '0WA0'],
#  ['6571',
#   '00WA',
#   'small_airport',
#   'Howell Airport',
#   '47.17839813',
#   '-122.7720032',
#   '150',
#   'NA',
#   'US',
#   'US-WA',
#   'Longbranch',
#   'no',
#   '00WA',
#   '',
#   '00WA',
#   '',
#   '',
#   ''],
#  ['6572',
#   '00WI',
#   'small_airport',
#   'Northern Lite Airport',
#   '44.3042984',
#   '-89.05010223',
#   '860',
#   'NA',
#   'US',
#   'US-WI',
#   'Waupaca',
#   'no',
#   '00WI',
#   '',
#   '00WI',
#   '',
#   '',
#   ''],
#  ['6573',
#   '00WN',
#   'small_airport',
#   'Hawks Run Airport',
#   '46.25',
#   '-117.2490005',
#   '2900',
#   'NA',
#   'US',
#   'US-WA',
#   'Asotin',
#   'no',
#   '00WN',
#   '',
#   '00WN',
#   '',
#   '',
#   ''],
#  ['6574',
#   '00WV',
#   'small_airport',
#   'Lazy J. Aerodrome',
#   '38.82889938',
#   '-79.8660965',
#   '2060',
#   'NA',
#   'US',
#   'US-WV',
#   'Beverly',
#   'no',
#   '00WV',
#   '',
#   '00WV',
#   '',
#   '',
#   ''],
#  ['322300',
#   '00WY',
#   'heliport',
#   'Mountain View Regional Hospital Heliport',
#   '42.840361',
#   '-106.224443',
#   '5210',
#   'NA',
#   'US',
#   'US-WY',
#   'Casper',
#   'no',
#   '00WY',
#   '',
#   '00WY',
#   '',
#   '',
#   ''],
#  ['6575',
#   '00XS',
#   'small_airport',
#   'L P Askew Farms Airport',
#   '33.03340149',
#   '-101.9339981',
#   '3110',
#   'NA',
#   'US',
#   'US-TX',
#   "O'Donnell",
#   'no',
#   '00XS',
#   '',
#   '00XS',
#   '',
#   '',
#   ''],
#  ['6576',
#   '01A',
#   'small_airport',
#   'Purkeypile Airport',
#   '62.9435997',
#   '-152.2700043',
#   '1950',
#   'NA',
#   'US',
#   'US-AK',
#   'Purkeypile',
#   'no',
#   '01A',
#   '',
#   '01A',
#   '',
#   '',
#   ''],
#  ['6577',
#   '01AK',
#   'heliport',
#   'Providence Seward Medical Center Heliport',
#   '60.10587398',
#   '-149.446249',
#   '120',
#   'NA',
#   'US',
#   'US-AK',
#   'Seward',
#   'no',
#   '01AK',
#   '',
#   '01AK',
#   '',
#   '',
#   ''],
#  ['6578',
#   '01AL',
#   'small_airport',
#   'Ware Island Airport',
#   '32.94599915',
#   '-86.51390076',
#   '344',
#   'NA',
#   'US',
#   'US-AL',
#   'Clanton',
#   'no',
#   '01AL',
#   '',
#   '01AL',
#   '',
#   '',
#   ''],
#  ['6579',
#   '01AR',
#   'heliport',
#   'Community Hospital of De Queen Heliport',
#   '34.04729843',
#   '-94.35489655',
#   '400',
#   'NA',
#   'US',
#   'US-AR',
#   'De Queen',
#   'no',
#   '01AR',
#   '',
#   '01AR',
#   '',
#   '',
#   ''],
#  ['6580',
#   '01AZ',
#   'heliport',
#   'Yat Heliport',
#   '34.60810089',
#   '-111.8649979',
#   '3300',
#   'NA',
#   'US',
#   'US-AZ',
#   'Camp Verde',
#   'no',
#   '01AZ',
#   '',
#   '01AZ',
#   '',
#   '',
#   ''],
#  ['6581',
#   '01C',
#   'closed',
#   'Grant Airport',
#   '43.34170151',
#   '-85.77500153',
#   '815',
#   'NA',
#   'US',
#   'US-MI',
#   'Grant',
#   'no',
#   '01C',
#   '',
#   '01C',
#   '',
#   'https://en.wikipedia.org/wiki/Grant_Airport',
#   ''],
#  ['6582',
#   '01CA',
#   'heliport',
#   'Lugo Substation Heliport',
#   '34.36824059',
#   '-117.3700587',
#   '3733',
#   'NA',
#   'US',
#   'US-CA',
#   'Hesperia',
#   'no',
#   '01CA',
#   '',
#   '01CA',
#   '',
#   '',
#   ''],
#  ['6583',
#   '01CL',
#   'small_airport',
#   'Swansboro Country Airport',
#   '38.79990005',
#   '-120.7340012',
#   '2594',
#   'NA',
#   'US',
#   'US-CA',
#   'Placerville',
#   'no',
#   '01CL',
#   '',
#   '01CL',
#   '',
#   '',
#   ''],
#  ['6584',
#   '01CN',
#   'heliport',
#   "Los Angeles County Sheriff's Department Heliport",
#   '34.03779984',
#   '-118.1539993',
#   '300',
#   'NA',
#   'US',
#   'US-CA',
#   'Los Angeles',
#   'no',
#   '01CN',
#   '',
#   '01CN',
#   '',
#   '',
#   ''],
#  ['6585',
#   '01CO',
#   'heliport',
#   'St Vincent General Hospital Heliport',
#   '39.24530029',
#   '-106.2460022',
#   '10175',
#   'NA',
#   'US',
#   'US-CO',
#   'Leadville',
#   'no',
#   '01CO',
#   '',
#   '01CO',
#   '',
#   '',
#   ''],
#  ['6586',
#   '01CT',
#   'heliport',
#   'Berlin Fairgrounds Heliport',
#   '41.62730026',
#   '-72.72750092',
#   '60',
#   'NA',
#   'US',
#   'US-CT',
#   'Berlin',
#   'no',
#   '01CT',
#   '',
#   '01CT',
#   '',
#   '',
#   ''],
#  ['6587',
#   '01FA',
#   'small_airport',
#   'Rybolt Ranch Airport',
#   '28.58939934',
#   '-81.14420319',
#   '55',
#   'NA',
#   'US',
#   'US-FL',
#   'Orlando',
#   'no',
#   '01FA',
#   '',
#   '01FA',
#   '',
#   '',
#   ''],
#  ['6588',
#   '01FD',
#   'heliport',
#   'Advent Health Altamonte Springs Heliport',
#   '28.666639',
#   '-81.3697',
#   '86',
#   'NA',
#   'US',
#   'US-FL',
#   'Altamonte Springs',
#   'no',
#   '01FD',
#   '',
#   '01FD',
#   '',
#   '',
#   'Florida Hospital-Altamonte'],
#  ['6589',
#   '01FL',
#   'small_airport',
#   'Cedar Knoll Flying Ranch Airport',
#   '28.78190041',
#   '-81.15920258',
#   '19',
#   'NA',
#   'US',
#   'US-FL',
#   'Geneva',
#   'no',
#   '01FL',
#   '',
#   '01FL',
#   '',
#   '',
#   ''],
#  ['6590',
#   '01GA',
#   'heliport',
#   'Medical Center Heliport',
#   '32.47930145',
#   '-84.97910309',
#   '319',
#   'NA',
#   'US',
#   'US-GA',
#   'Columbus',
#   'no',
#   '01GA',
#   '',
#   '01GA',
#   '',
#   '',
#   ''],
#  ['6591',
#   '01GE',
#   'small_airport',
#   'The Farm Airport',
#   '32.67440033',
#   '-82.77110291',
#   '375',
#   'NA',
#   'US',
#   'US-GA',
#   'Wrightsville',
#   'no',
#   '01GE',
#   '',
#   '01GE',
#   '',
#   '',
#   ''],
#  ['6592',
#   '01IA',
#   'small_airport',
#   'Stender Airport',
#   '41.66109848',
#   '-90.74130249',
#   '725',
#   'NA',
#   'US',
#   'US-IA',
#   'Maysville',
#   'no',
#   '01IA',
#   '',
#   '01IA',
#   '',
#   '',
#   ''],
#  ['6530',
#   '01ID',
#   'small_airport',
#   'Lava Hot Springs Airport',
#   '42.6082',
#   '-112.031998',
#   '5268',
#   'NA',
#   'US',
#   'US-ID',
#   'Lava Hot Springs',
#   'no',
#   '01ID',
#   '',
#   '01ID',
#   '',
#   '',
#   '"Formerly 00E',
#   ' ID26"'],
#  ['6593',
#   '01II',
#   'small_airport',
#   'Myers Field',
#   '39.88499832',
#   '-86.50669861',
#   '950',
#   'NA',
#   'US',
#   'US-IN',
#   'Lizton',
#   'no',
#   '01II',
#   '',
#   '01II',
#   '',
#   '',
#   ''],
#  ['6594',
#   '01IL',
#   'heliport',
#   'Hoopeston Community Memorial Hospital Heliport',
#   '40.45859909',
#   '-87.65950012',
#   '583',
#   'NA',
#   'US',
#   'US-IL',
#   'Hoopeston',
#   'no',
#   '01IL',
#   '',
#   '01IL',
#   '',
#   '',
#   ''],
#  ['6595',
#   '01IN',
#   'heliport',
#   'Community Hospital Heliport',
#   '40.13090134',
#   '-85.69580078',
#   '890',
#   'NA',
#   'US',
#   'US-IN',
#   'Anderson',
#   'no',
#   '01IN',
#   '',
#   '01IN',
#   '',
#   '',
#   ''],
#  ['6596',
#   '01IS',
#   'small_airport',
#   'William E. Koenig Airport',
#   '39.01620102',
#   '-90.31819916',
#   '670',
#   'NA',
#   'US',
#   'US-IL',
#   'Dow',
#   'no',
#   '01IS',
#   '',
#   '01IS',
#   '',
#   '',
#   ''],
#  ['6597',
#   '01J',
#   'small_airport',
#   'Hilliard Airpark',
#   '30.68630028',
#   '-81.90570068',
#   '59',
#   'NA',
#   'US',
#   'US-FL',
#   'Hilliard',
#   'no',
#   '01J',
#   '',
#   '01J',
#   '',
#   '',
#   ''],
#  ['6598',
#   '01K',
#   'small_airport',
#   'Caldwell Municipal Airport',
#   '37.03609848',
#   '-97.58640289',
#   '1157',
#   'NA',
#   'US',
#   'US-KS',
#   'Caldwell',
#   'no',
#   '01K',
#   '',
#   '01K',
#   '',
#   '',
#   ''],
#  ['6599',
#   '01KS',
#   'small_airport',
#   'Flying N Ranch Airport',
#   '38.54059982',
#   '-97.00330353',
#   '1485',
#   'NA',
#   'US',
#   'US-KS',
#   'Lost Springs',
#   'no',
#   '01KS',
#   '',
#   '01KS',
#   '',
#   '',
#   ''],
#  ['6600',
#   '01KY',
#   'heliport',
#   'Lourdes Hospital Heliport',
#   '37.05170059',
#   '-88.64689636',
#   '419',
#   'NA',
#   'US',
#   'US-KY',
#   'Paducah',
#   'no',
#   '01KY',
#   '',
#   '01KY',
#   '',
#   '',
#   ''],
#  ['6601',
#   '01LA',
#   'small_airport',
#   'Barham Airport',
#   '32.63899994',
#   '-91.7736969',
#   '90',
#   'NA',
#   'US',
#   'US-LA',
#   'Oak Ridge',
#   'no',
#   '01LA',
#   '',
#   '01LA',
#   '',
#   '',
#   ''],
#  ['6602',
#   '01LL',
#   'small_airport',
#   'Schumaier Restricted Landing Area',
#   '38.12580109',
#   '-89.46389771',
#   '555',
#   'NA',
#   'US',
#   'US-IL',
#   'Pinckneyville',
#   'no',
#   '01LL',
#   '',
#   '01LL',
#   '',
#   '',
#   ''],
#  ['6603',
#   '01LS',
#   'small_airport',
#   'Country Breeze Airport',
#   '30.70599937',
#   '-91.07740021',
#   '125',
#   'NA',
#   'US',
#   'US-LA',
#   'Slaughter',
#   'no',
#   '01LS',
#   '',
#   '01LS',
#   '',
#   '',
#   ''],
#  ['6604',
#   '01MA',
#   'heliport',
#   'Compaq Andover Heliport',
#   '42.62509918',
#   '-71.18009949',
#   '140',
#   'NA',
#   'US',
#   'US-MA',
#   'Andover',
#   'no',
#   '01MA',
#   '',
#   '01MA',
#   '',
#   '',
#   ''],
#  ['6605',
#   '01MD',
#   'seaplane_base',
#   'Annapolis Seaplane Base',
#   '38.999199',
#   '-76.456001',
#   '',
#   'NA',
#   'US',
#   'US-MD',
#   'Annapolis',
#   'no',
#   '01MD',
#   '',
#   '01MD',
#   '',
#   '',
#   ''],
#  ['6606',
#   '01ME',
#   'seaplane_base',
#   "Saint Peter's Seaplane Base",
#   '46.77890015',
#   '-68.50029755',
#   '608',
#   'NA',
#   'US',
#   'US-ME',
#   'Portage Lake',
#   'no',
#   '01ME',
#   '',
#   '01ME',
#   '',
#   '',
#   ''],
#  ['6607',
#   '01MI',
#   'heliport',
#   'Flow Through Terminal Heliport',
#   '43.04949951',
#   '-83.67970276',
#   '736',
#   'NA',
#   'US',
#   'US-MI',
#   'Flint',
#   'no',
#   '01MI',
#   '',
#   '01MI',
#   '',
#   '',
#   ''],
#  ['6608',
#   '01MN',
#   'seaplane_base',
#   'Barnes Seaplane Base',
#   '47.89960098',
#   '-92.55740356',
#   '1358',
#   'NA',
#   'US',
#   'US-MN',
#   'Cook',
#   'no',
#   '01MN',
#   '',
#   '01MN',
#   '',
#   '',
#   ''],
#  ['6609',
#   '01MO',
#   'heliport',
#   'Highway Patrol Troop C Headquarters Heliport',
#   '38.64170074',
#   '-90.48429871',
#   '615',
#   'NA',
#   'US',
#   'US-MO',
#   'Town and Country',
#   'no',
#   '01MO',
#   '',
#   '01MO',
#   '',
#   '',
#   ''],
#  ['6610',
#   '01MT',
#   'small_airport',
#   'Crystal Lakes Resort Airport',
#   '48.78910065',
#   '-114.8799973',
#   '3141',
#   'NA',
#   'US',
#   'US-MT',
#   'Fortine',
#   'no',
#   '01MT',
#   '',
#   '01MT',
#   '',
#   '',
#   ''],
#  ['6611',
#   '01NC',
#   'small_airport',
#   'Topsail Airpark',
#   '34.47529984',
#   '-77.58139801',
#   '65',
#   'NA',
#   'US',
#   'US-NC',
#   'Holly Ridge',
#   'no',
#   '01NC',
#   '',
#   '01NC',
#   '',
#   '',
#   ''],
#  ['6612',
#   '01NE',
#   'small_airport',
#   'Detour Airport',
#   '40.84360123',
#   '-100.6529999',
#   '3000',
#   'NA',
#   'US',
#   'US-NE',
#   'Wellfleet',
#   'no',
#   '01NE',
#   '',
#   '01NE',
#   '',
#   '',
#   ''],
#  ['6613',
#   '01NH',
#   'small_airport',
#   'Moore Airfield',
#   '43.6445',
#   '-72.086998',
#   '835',
#   'NA',
#   'US',
#   'US-NH',
#   'Canaan',
#   'no',
#   '01NH',
#   '',
#   '01NH',
#   '',
#   '',
#   'Enfield'],
#  ['6614',
#   '01NJ',
#   'heliport',
#   'Albert Guido Memorial Heliport',
#   '40.7417984',
#   '-74.13710022',
#   '10',
#   'NA',
#   'US',
#   'US-NJ',
#   'Newark',
#   'no',
#   '01NJ',
#   '',
#   '01NJ',
#   '',
#   '',
#   ''],
#  ['45537',
#   '01NM',
#   'small_airport',
#   'Champion Ranch Airport',
#   '33.008611',
#   '-104.540278',
#   '3630',
#   'NA',
#   'US',
#   'US-NM',
#   'Artesia',
#   'no',
#   '01NM',
#   '',
#   '01NM',
#   '',
#   '',
#   ''],
#  ['6615',
#   '01NV',
#   'small_airport',
#   'Lantana Ranch Airport',
#   '38.76390076',
#   '-119.0270004',
#   '4600',
#   'NA',
#   'US',
#   'US-NV',
#   'Yerington',
#   'no',
#   '01NV',
#   '',
#   '01NV',
#   '',
#   '',
#   ''],
#  ['6616',
#   '01NY',
#   'closed',
#   'Vassar Hospital Heliport',
#   '41.694187',
#   '-73.935582',
#   '100',
#   'NA',
#   'US',
#   'US-NY',
#   'Poughkeepsie',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '01NY'],
#  ['6617',
#   '01OI',
#   'heliport',
#   'Galion Community Hospital Heliport',
#   '40.73059845',
#   '-82.8015976',
#   '1140',
#   'NA',
#   'US',
#   'US-OH',
#   'Galion',
#   'no',
#   '01OI',
#   '',
#   '01OI',
#   '',
#   '',
#   ''],
#  ['6618',
#   '01OK',
#   'closed',
#   'Lawrence Airport',
#   '35.294498',
#   '-98.636496',
#   '1525',
#   'NA',
#   'US',
#   'US-OK',
#   'Eakly',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '01OK'],
#  ['6619',
#   '01OR',
#   'closed',
#   'Red & White Flying Service Airport',
#   '43.119301',
#   '-121.044997',
#   '4346',
#   'NA',
#   'US',
#   'US-OR',
#   'Silver Lake',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '01OR'],
#  ['6620',
#   '01PA',
#   'heliport',
#   'Pine Heliport',
#   '40.6556015',
#   '-80.05090332',
#   '1215',
#   'NA',
#   'US',
#   'US-PA',
#   'Mars',
#   'no',
#   '01PA',
#   '',
#   '01PA',
#   '',
#   '',
#   ''],
#  ['6621',
#   '01PN',
#   'small_airport',
#   'Bierly(Personal Use) Airport',
#   '40.93059921',
#   '-77.73889923',
#   '960',
#   'NA',
#   'US',
#   'US-PA',
#   'Bellefonte',
#   'no',
#   '01PN',
#   '',
#   '01PN',
#   '',
#   '',
#   ''],
#  ['6622',
#   '01PS',
#   'small_airport',
#   "Nort's Resort Airport",
#   '41.59590149',
#   '-76.02960205',
#   '1040',
#   'NA',
#   'US',
#   'US-PA',
#   'Meshoppen',
#   'no',
#   '01PS',
#   '',
#   '01PS',
#   '',
#   '',
#   ''],
#  ['6623',
#   '01SC',
#   'small_airport',
#   'York Airport',
#   '35.03210068',
#   '-81.25279999',
#   '779',
#   'NA',
#   'US',
#   'US-SC',
#   'York',
#   'no',
#   '01SC',
#   '',
#   '01SC',
#   '',
#   '',
#   ''],
#  ['6624',
#   '01TA',
#   'heliport',
#   'Thirty Thirty Matlock Office Center Heliport',
#   '32.69419861',
#   '-97.11579895',
#   '630',
#   'NA',
#   'US',
#   'US-TX',
#   'Arlington',
#   'no',
#   '01TA',
#   '',
#   '01TA',
#   '',
#   '',
#   ''],
#  ['6625',
#   '01TE',
#   'small_airport',
#   'Smith Field',
#   '32.73759842',
#   '-96.4280014',
#   '505',
#   'NA',
#   'US',
#   'US-TX',
#   'Forney',
#   'no',
#   '01TE',
#   '',
#   '01TE',
#   '',
#   '',
#   ''],
#  ['6626',
#   '01TN',
#   'small_airport',
#   'Colonial Air Park',
#   '34.9958992',
#   '-89.73059845',
#   '370',
#   'NA',
#   'US',
#   'US-TN',
#   'Collierville',
#   'no',
#   '01TN',
#   '',
#   '01TN',
#   '',
#   '',
#   ''],
#  ['6627',
#   '01TS',
#   'closed',
#   'St Joseph Hospital Heliport',
#   '32.7285',
#   '-97.324501',
#   '675',
#   'NA',
#   'US',
#   'US-TX',
#   'Fort Worth',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '01TS'],
#  ['6628',
#   '01TX',
#   'small_airport',
#   'Mims Farm Ultralightport',
#   '32.38759995',
#   '-96.87750244',
#   '610',
#   'NA',
#   'US',
#   'US-TX',
#   'Waxahachie',
#   'no',
#   '01TX',
#   '',
#   '01TX',
#   '',
#   '',
#   ''],
#  ['6629',
#   '01U',
#   'small_airport',
#   'Duckwater Airport',
#   '38.85160065',
#   '-115.6340027',
#   '5124',
#   'NA',
#   'US',
#   'US-NV',
#   'Duckwater',
#   'no',
#   '01U',
#   '',
#   '01U',
#   '',
#   '',
#   ''],
#  ['6630',
#   '01UT',
#   'small_airport',
#   'La Sal Junction Airport',
#   '38.30830002',
#   '-109.3960037',
#   '6000',
#   'NA',
#   'US',
#   'US-UT',
#   'La Sal',
#   'no',
#   '01UT',
#   '',
#   '01UT',
#   '',
#   '',
#   ''],
#  ['6631',
#   '01VA',
#   'small_airport',
#   'Pickles Airport',
#   '39.125',
#   '-77.92500305',
#   '500',
#   'NA',
#   'US',
#   'US-VA',
#   'Berryville',
#   'no',
#   '01VA',
#   '',
#   '01VA',
#   '',
#   '',
#   ''],
#  ['6632',
#   '01WA',
#   'heliport',
#   'Willapa Harbor Heliport',
#   '46.66320038',
#   '-123.8119965',
#   '154',
#   'NA',
#   'US',
#   'US-WA',
#   'South Bend',
#   'no',
#   '01WA',
#   '',
#   '01WA',
#   '',
#   '',
#   ''],
#  ['6633',
#   '01WI',
#   'small_airport',
#   'Prehn Cranberry Company Airport',
#   '44.00999832',
#   '-90.3891983',
#   '930',
#   'NA',
#   'US',
#   'US-WI',
#   'Tomah',
#   'no',
#   '01WI',
#   '',
#   '01WI',
#   '',
#   '',
#   ''],
#  ['6634',
#   '01WN',
#   'heliport',
#   'Whidbey General Hospital Heliport',
#   '48.21340179',
#   '-122.6849976',
#   '103',
#   'NA',
#   'US',
#   'US-WA',
#   'Coupeville',
#   'no',
#   '01WN',
#   '',
#   '01WN',
#   '',
#   '',
#   ''],
#  ['45900',
#   '01WT',
#   'heliport',
#   'Odyssey Heliport',
#   '47.518178',
#   '-122.210908',
#   '20',
#   'NA',
#   'US',
#   'US-WA',
#   'Renton',
#   'no',
#   '01WT',
#   '',
#   '01WT',
#   '',
#   '',
#   ''],
#  ['6635',
#   '01WY',
#   'small_airport',
#   'Keyhole Airport',
#   '44.34719849',
#   '-104.810997',
#   '4250',
#   'NA',
#   'US',
#   'US-WY',
#   'Moorcroft',
#   'no',
#   '01WY',
#   '',
#   '01WY',
#   '',
#   '',
#   ''],
#  ['46288',
#   '01XA',
#   'heliport',
#   'Seton Medical Center Hays Heliport',
#   '30.007222',
#   '-97.853333',
#   '715',
#   'NA',
#   'US',
#   'US-TX',
#   'Kyle',
#   'no',
#   '01XA',
#   '',
#   '01XA',
#   '',
#   '',
#   ''],
#  ['6636',
#   '01XS',
#   'heliport',
#   'Meadowood Ranch Heliport',
#   '32.02019882',
#   '-95.74549866',
#   '500',
#   'NA',
#   'US',
#   'US-TX',
#   'Athens',
#   'no',
#   '01XS',
#   '',
#   '01XS',
#   '',
#   '',
#   ''],
#  ['6637',
#   '02AK',
#   'small_airport',
#   'Rustic Wilderness Airport',
#   '61.87689972',
#   '-150.0980072',
#   '190',
#   'NA',
#   'US',
#   'US-AK',
#   'Willow',
#   'no',
#   '02AK',
#   '',
#   '02AK',
#   '',
#   '',
#   ''],
#  ['6638',
#   '02AL',
#   'small_airport',
#   'Bass Field',
#   '30.37150002',
#   '-87.76439667',
#   '61',
#   'NA',
#   'US',
#   'US-AL',
#   'Foley',
#   'no',
#   '02AL',
#   '',
#   '02AL',
#   '',
#   '',
#   ''],
#  ['43030',
#   '02AR',
#   'closed',
#   'Three Rivers Airport',
#   '34.822445',
#   '-92.44442',
#   '264',
#   'NA',
#   'US',
#   'US-AR',
#   'Little Rock',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '02AR'],
#  ['6640',
#   '02AZ',
#   'closed',
#   'Winchester Farm Airstrip',
#   '32.376401',
#   '-109.936996',
#   '4200',
#   'NA',
#   'US',
#   'US-AZ',
#   'Willcox',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '02AZ'],
#  ['6641',
#   '02CA',
#   'heliport',
#   'Swepi Beta Platform Ellen Heliport',
#   '33.58250046',
#   '-118.1289978',
#   '122',
#   'NA',
#   'US',
#   'US-CA',
#   'Huntington Beach',
#   'no',
#   '02CA',
#   '',
#   '02CA',
#   '',
#   '',
#   ''],
#  ['6642',
#   '02CD',
#   'small_airport',
#   'Shannon Field',
#   '34.12960052',
#   '-90.52400208',
#   '165',
#   'NA',
#   'US',
#   'US-MS',
#   'Clarksdale',
#   'no',
#   '02CD',
#   '',
#   '02CD',
#   '',
#   '',
#   ''],
#  ['6643',
#   '02CL',
#   'small_airport',
#   'Conover Air Lodge Airport',
#   '34.761101',
#   '-119.058998',
#   '5160',
#   'NA',
#   'US',
#   'US-CA',
#   'Frazier Park',
#   'no',
#   '02CL',
#   '',
#   '02CL',
#   '',
#   '',
#   '04L'],
#  ['6644',
#   '02CO',
#   'small_airport',
#   'Mc Cullough Airport',
#   '37.6432991',
#   '-106.0469971',
#   '7615',
#   'NA',
#   'US',
#   'US-CO',
#   'Monte Vista',
#   'no',
#   '02CO',
#   '',
#   '02CO',
#   '',
#   '',
#   ''],
#  ['6645',
#   '02CT',
#   'heliport',
#   'Strangers Point Heliport',
#   '41.91960144',
#   '-72.44450378',
#   '540',
#   'NA',
#   'US',
#   'US-CT',
#   'Ellington',
#   'no',
#   '02CT',
#   '',
#   '02CT',
#   '',
#   '',
#   ''],
#  ['6646',
#   '02FA',
#   'small_airport',
#   'Osborn Airfield',
#   '28.52669907',
#   '-81.87480164',
#   '121',
#   'NA',
#   'US',
#   'US-FL',
#   'Groveland',
#   'no',
#   '02FA',
#   '',
#   '02FA',
#   '',
#   '',
#   ''],
#  ['45347',
#   '02FL',
#   'small_airport',
#   'Cuchens Airport',
#   '30.642778',
#   '-86.123889',
#   '215',
#   'NA',
#   'US',
#   'US-FL',
#   'Defuniak Springs',
#   'no',
#   '02FL',
#   '',
#   '02FL',
#   '',
#   '',
#   ''],
#  ['6648',
#   '02GA',
#   'small_airport',
#   'Doug Bolton Field',
#   '34.20259857',
#   '-83.42900085',
#   '884',
#   'NA',
#   'US',
#   'US-GA',
#   'Commerce',
#   'no',
#   '02GA',
#   '',
#   '02GA',
#   '',
#   '',
#   ''],
#  ['6649',
#   '02GE',
#   'small_airport',
#   'Etowah Fields Airport',
#   '34.1753006',
#   '-84.92440033',
#   '710',
#   'NA',
#   'US',
#   'US-GA',
#   'Euharlee',
#   'no',
#   '02GE',
#   '',
#   '02GE',
#   '',
#   '',
#   ''],
#  ['6650',
#   '02HI',
#   'heliport',
#   'K3 Helipad Heliport',
#   '21.36199951',
#   '-157.951004',
#   '9',
#   'NA',
#   'US',
#   'US-HI',
#   'Pearl Harbor',
#   'no',
#   '02HI',
#   '',
#   '02HI',
#   '',
#   '',
#   ''],
#  ['6651',
#   '02IA',
#   'heliport',
#   'Boone County Hospital Heliport',
#   '42.05609894',
#   '-93.87799835',
#   '1160',
#   'NA',
#   'US',
#   'US-IA',
#   'Boone',
#   'no',
#   '02IA',
#   '',
#   '02IA',
#   '',
#   '',
#   ''],
#  ['6652',
#   '02ID',
#   'small_airport',
#   'Morgan Ranch Airport',
#   '44.55550003',
#   '-115.3050003',
#   '5634',
#   'NA',
#   'US',
#   'US-ID',
#   'Cascade',
#   'no',
#   '02ID',
#   '',
#   '02ID',
#   '',
#   '',
#   ''],
#  ['6653',
#   '02II',
#   'small_airport',
#   'King Ultralightport',
#   '40.06230164',
#   '-86.21050262',
#   '925',
#   'NA',
#   'US',
#   'US-IN',
#   'Westfield',
#   'no',
#   '02II',
#   '',
#   '02II',
#   '',
#   '',
#   ''],
#  ['6654',
#   '02IN',
#   'small_airport',
#   'Diamond P. Field',
#   '40.20890045',
#   '-85.540802',
#   '904',
#   'NA',
#   'US',
#   'US-IN',
#   'Muncie',
#   'no',
#   '02IN',
#   '',
#   '02IN',
#   '',
#   '',
#   ''],
#  ['6655',
#   '02IS',
#   'heliport',
#   'Condell Medical Center Heliport',
#   '42.27460098',
#   '-87.95729828',
#   '762',
#   'NA',
#   'US',
#   'US-IL',
#   'Libertyville',
#   'no',
#   '02IS',
#   '',
#   '02IS',
#   '',
#   '',
#   ''],
#  ['6656',
#   '02KS',
#   'small_airport',
#   'Jmj Landing Airport',
#   '39.22219849',
#   '-96.05529785',
#   '1170',
#   'NA',
#   'US',
#   'US-KS',
#   'St Marys',
#   'no',
#   '02KS',
#   '',
#   '02KS',
#   '',
#   '',
#   ''],
#  ['327110',
#   '02KT',
#   'heliport',
#   'St Claire Healthcare Heliport',
#   '38.181441',
#   '-83.443319',
#   '781',
#   'NA',
#   'US',
#   'US-KY',
#   'Morehead',
#   'no',
#   '02KT',
#   '',
#   '02KT',
#   '',
#   '',
#   ''],
#  ['6657',
#   '02KY',
#   'heliport',
#   'Boone National Guard Heliport',
#   '38.1833992',
#   '-84.89990234',
#   '760',
#   'NA',
#   'US',
#   'US-KY',
#   'Frankfort',
#   'no',
#   '02KY',
#   '',
#   '02KY',
#   '',
#   '',
#   ''],
#  ['6658',
#   '02LA',
#   'heliport',
#   'La State Police Troop G Heliport',
#   '32.53129959',
#   '-93.66020203',
#   '168',
#   'NA',
#   'US',
#   'US-LA',
#   'Bossier City',
#   'no',
#   '02LA',
#   '',
#   '02LA',
#   '',
#   '',
#   ''],
#  ['6659',
#   '02LS',
#   'heliport',
#   'Windy Hill Heliport',
#   '30.14830017',
#   '-91.91899872',
#   '25',
#   'NA',
#   'US',
#   'US-LA',
#   'Broussard',
#   'no',
#   '02LS',
#   '',
#   '02LS',
#   '',
#   '',
#   ''],
#  ['6660',
#   '02MA',
#   'heliport',
#   'Cuttyhunk Heliport',
#   '41.41960144',
#   '-70.92700195',
#   '9',
#   'NA',
#   'US',
#   'US-MA',
#   'Gosnold',
#   'no',
#   '02MA',
#   '',
#   '02MA',
#   '',
#   '',
#   ''],
#  ['322099',
#   '02MD',
#   'small_airport',
#   'Garner Field',
#   '38.672544',
#   '-76.709739',
#   '141',
#   'NA',
#   'US',
#   'US-MD',
#   'Brandywine',
#   'no',
#   '02MD',
#   '',
#   '02MD',
#   '',
#   '',
#   ''],
#  ['6661',
#   '02ME',
#   'small_airport',
#   "Nadeau's Airport",
#   '43.5373',
#   '-70.929397',
#   '700',
#   'NA',
#   'US',
#   'US-ME',
#   'Acton',
#   'no',
#   '02ME',
#   '',
#   '02ME',
#   '',
#   '',
#   'Old Acton Airfield'],
#  ['6662',
#   '02MI',
#   'small_airport',
#   'Fairplains Airpark',
#   '43.15710068',
#   '-85.14849854',
#   '850',
#   'NA',
#   'US',
#   'US-MI',
#   'Greenville',
#   'no',
#   '02MI',
#   '',
#   '02MI',
#   '',
#   '',
#   ''],
#  ['6663',
#   '02MN',
#   'small_airport',
#   'Greenbush Municipal Airport',
#   '48.68330002',
#   '-96.19200134',
#   '1070',
#   'NA',
#   'US',
#   'US-MN',
#   'Greenbush',
#   'no',
#   '02MN',
#   '',
#   '02MN',
#   '',
#   '',
#   ''],
#  ['6664',
#   '02MO',
#   'small_airport',
#   'Troy Airpark',
#   '39.04999924',
#   '-91.03350067',
#   '650',
#   'NA',
#   'US',
#   'US-MO',
#   'Troy',
#   'no',
#   '02MO',
#   '',
#   '02MO',
#   '',
#   '',
#   ''],
#  ['6665',
#   '02MS',
#   'small_airport',
#   'Watts Field',
#   '34.10010147',
#   '-90.84680176',
#   '153',
#   'NA',
#   'US',
#   'US-MS',
#   'Rochdale',
#   'no',
#   '02MS',
#   '',
#   '02MS',
#   '',
#   '',
#   ''],
#  ['6666',
#   '02MT',
#   'closed',
#   'Barrett Field',
#   '47.2374',
#   '-111.74304',
#   '3350',
#   'NA',
#   'US',
#   'US-MT',
#   'Cascade',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '02MT'],
#  ['6667',
#   '02MU',
#   'closed',
#   'Timber Line Airpark',
#   '36.654233',
#   '-93.797418',
#   '1550',
#   'NA',
#   'US',
#   'US-MO',
#   'Cassville',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '02MU'],
#  ['45686',
#   '02NC',
#   'heliport',
#   'Race City Heliport',
#   '35.541111',
#   '-80.597778',
#   '809',
#   'NA',
#   'US',
#   'US-NC',
#   'Landis',
#   'no',
#   '02NC',
#   '',
#   '02NC',
#   '',
#   '',
#   ''],
#  ['6668',
#   '02NE',
#   'small_airport',
#   'Benes Service Airport',
#   '41.07450104',
#   '-96.90450287',
#   '1550',
#   'NA',
#   'US',
#   'US-NE',
#   'Valparaiso',
#   'no',
#   '02NE',
#   '',
#   '02NE',
#   '',
#   '',
#   ''],
#  ['6669',
#   '02NH',
#   'seaplane_base',
#   'Iroquois Landing Seaplane Base',
#   '44.65710068',
#   '-71.21910095',
#   '1180',
#   'NA',
#   'US',
#   'US-NH',
#   'Dummer',
#   'no',
#   '02NH',
#   '',
#   '02NH',
#   '',
#   '',
#   ''],
#  ['6670',
#   '02NJ',
#   'heliport',
#   'Penske Heliport',
#   '40.55730057',
#   '-74.46710205',
#   '78',
#   'NA',
#   'US',
#   'US-NJ',
#   'Piscataway',
#   'no',
#   '02NJ',
#   '',
#   '02NJ',
#   '',
#   '',
#   ''],
#  ['6671',
#   '02NV',
#   'small_airport',
#   'Paiute Meadows Airport',
#   '41.30329895',
#   '-118.5979996',
#   '4443',
#   'NA',
#   'US',
#   'US-NV',
#   'Winnemucca',
#   'no',
#   '02NV',
#   '',
#   '02NV',
#   '',
#   '',
#   ''],
#  ['6672',
#   '02NY',
#   'heliport',
#   'Hansen Heliport',
#   '43.13259888',
#   '-75.65550232',
#   '435',
#   'NA',
#   'US',
#   'US-NY',
#   'Durhamville',
#   'no',
#   '02NY',
#   '',
#   '02NY',
#   '',
#   '',
#   ''],
#  ['6673',
#   '02OH',
#   'small_airport',
#   'Zimmerman Airport',
#   '41.37639999',
#   '-83.08329773',
#   '614',
#   'NA',
#   'US',
#   'US-OH',
#   'Fremont',
#   'no',
#   '02OH',
#   '',
#   '02OH',
#   '',
#   '',
#   ''],
#  ['6674',
#   '02OI',
#   'small_airport',
#   'Murtha Airport',
#   '41.80199814',
#   '-80.56539917',
#   '950',
#   'NA',
#   'US',
#   'US-OH',
#   'Conneaut',
#   'no',
#   '02OI',
#   '',
#   '02OI',
#   '',
#   '',
#   ''],
#  ['6675',
#   '02OK',
#   'closed',
#   'Canon Heliport',
#   '35.458401',
#   '-97.525297',
#   '1191',
#   'NA',
#   'US',
#   'US-OK',
#   'Oklahoma City',
#   'no',
#   '',
#   '',
#   '02OK',
#   '',
#   '',
#   '02OK'],
#  ['6676',
#   '02OR',
#   'small_airport',
#   'Rowena Dell Airport',
#   '45.68149948',
#   '-121.3160019',
#   '705',
#   'NA',
#   'US',
#   'US-OR',
#   'The Dalles',
#   'no',
#   '02OR',
#   '',
#   '02OR',
#   '',
#   '',
#   ''],
#  ['6677',
#   '02P',
#   'heliport',
#   'Stottle Memorial Heliport',
#   '40.403596',
#   '-77.556602',
#   '591',
#   'NA',
#   'US',
#   'US-PA',
#   'Honey Grove',
#   'no',
#   '',
#   '',
#   '02P',
#   '',
#   '',
#   '"EWT 4',
#   '"'],
#  ['6678',
#   '02PA',
#   'heliport',
#   'Lag Iii Heliport',
#   '40.43830109',
#   '-79.76999664',
#   '1070',
#   'NA',
#   'US',
#   'US-PA',
#   'Monroeville',
#   'no',
#   '02PA',
#   '',
#   '02PA',
#   '',
#   '',
#   ''],
#  ['6679',
#   '02PN',
#   'heliport',
#   'Peco Berwyn Heliport',
#   '40.06959915',
#   '-75.4552002',
#   '390',
#   'NA',
#   'US',
#   'US-PA',
#   'Berwyn',
#   'no',
#   '02PN',
#   '',
#   '02PN',
#   '',
#   '',
#   ''],
#  ['6680',
#   '02PR',
#   'small_airport',
#   'Cuylers Airport',
#   '18.45330048',
#   '-66.36689758',
#   '15',
#   'NA',
#   'PR',
#   'PR-U-A',
#   'Vega Baja',
#   'no',
#   '02PR',
#   '',
#   '02PR',
#   '',
#   '',
#   ''],
#  ['6681',
#   '02PS',
#   'small_airport',
#   'Hughes Ultralightport',
#   '41.90060043',
#   '-77.2303009',
#   '1700',
#   'NA',
#   'US',
#   'US-PA',
#   'Tioga',
#   'no',
#   '02PS',
#   '',
#   '02PS',
#   '',
#   '',
#   ''],
#  ['6682',
#   '02SC',
#   'small_airport',
#   'Harpers Airport',
#   '32.75849915',
#   '-81.22480011',
#   '111',
#   'NA',
#   'US',
#   'US-SC',
#   'Estill',
#   'no',
#   '02SC',
#   '',
#   '02SC',
#   '',
#   '',
#   ''],
#  ['6683',
#   '02T',
#   'small_airport',
#   'Wise River Airport',
#   '45.76910019',
#   '-112.9820023',
#   '5830',
#   'NA',
#   'US',
#   'US-MT',
#   'Wise River',
#   'no',
#   '02T',
#   '',
#   '02T',
#   '',
#   '',
#   ''],
#  ['6684',
#   '02TA',
#   'heliport',
#   'Matagorda Shore Facility Heliport',
#   '28.72139931',
#   '-95.87380219',
#   '5',
#   'NA',
#   'US',
#   'US-TX',
#   'Matagorda',
#   'no',
#   '02TA',
#   '',
#   '02TA',
#   '',
#   '',
#   ''],
#  ['6685',
#   '02TE',
#   'heliport',
#   'Baylor Medical Center Heliport',
#   '32.395401',
#   '-96.86419678',
#   '560',
#   'NA',
#   'US',
#   'US-TX',
#   'Waxahachie',
#   'no',
#   '02TE',
#   '',
#   '02TE',
#   '',
#   '',
#   ''],
#  ['6686',
#   '02TN',
#   'small_airport',
#   'Ellis Field',
#   '35.7806015',
#   '-86.584198',
#   '840',
#   'NA',
#   'US',
#   'US-TN',
#   'Murfreesboro',
#   'no',
#   '02TN',
#   '',
#   '02TN',
#   '',
#   '',
#   ''],
#  ['6687',
#   '02TS',
#   'closed',
#   'FWOMC Heliport',
#   '32.747601',
#   '-97.370003',
#   '684',
#   'NA',
#   'US',
#   'US-TX',
#   'Fort Worth',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '02TS'],
#  ['6688',
#   '02TX',
#   'small_airport',
#   'The Palms At Kitty Hawk Airport',
#   '33.37040329',
#   '-101.9228821',
#   '3235',
#   'NA',
#   'US',
#   'US-TX',
#   'New Home',
#   'no',
#   '02TX',
#   '',
#   '02TX',
#   '',
#   '',
#   ''],
#  ['6689',
#   '02UT',
#   'small_airport',
#   'Lucin Airport',
#   '41.36629868',
#   '-113.8430023',
#   '4412',
#   'NA',
#   'US',
#   'US-UT',
#   'Lucin',
#   'no',
#   '02UT',
#   '',
#   '02UT',
#   '',
#   '',
#   ''],
#  ['6690',
#   '02VA',
#   'small_airport',
#   'The Greenhouse Airport',
#   '38.43569946',
#   '-77.85720062',
#   '320',
#   'NA',
#   'US',
#   'US-VA',
#   'Culpeper',
#   'no',
#   '02VA',
#   '',
#   '02VA',
#   '',
#   '',
#   ''],
#  ['6691',
#   '02VG',
#   'heliport',
#   'Northstar Aviation Heliport',
#   '36.63880157',
#   '-82.11669922',
#   '1850',
#   'NA',
#   'US',
#   'US-VA',
#   'Bristol',
#   'no',
#   '02VG',
#   '',
#   '02VG',
#   '',
#   '',
#   ''],
#  ['6692',
#   '02WA',
#   'small_airport',
#   'Cawleys South Prairie Airport',
#   '47.15230179',
#   '-122.0940018',
#   '690',
#   'NA',
#   'US',
#   'US-WA',
#   'South Prairie',
#   'no',
#   '02WA',
#   '',
#   '02WA',
#   '',
#   '',
#   ''],
#  ['6693',
#   '02WI',
#   'small_airport',
#   'Beer Airport',
#   '45.0318985',
#   '-92.65579987',
#   '920',
#   'NA',
#   'US',
#   'US-WI',
#   'Hudson',
#   'no',
#   '02WI',
#   '',
#   '02WI',
#   '',
#   '',
#   ''],
#  ['6694',
#   '02WN',
#   'small_airport',
#   'Fowler Field',
#   '48.74580002',
#   '-119.3190002',
#   '2150',
#   'NA',
#   'US',
#   'US-WA',
#   'Tonasket',
#   'no',
#   '02WN',
#   '',
#   '02WN',
#   '',
#   '',
#   ''],
#  ['330393',
#   '02XA',
#   'small_airport',
#   'JLS Farms Airport',
#   '33.591319',
#   '-95.882864',
#   '675',
#   'NA',
#   'US',
#   'US-TX',
#   'Honey Grove',
#   'no',
#   '02XA',
#   '',
#   '02XA',
#   '',
#   '',
#   ''],
#  ['6695',
#   '02XS',
#   'small_airport',
#   'Seidel Ranch Airport',
#   '30.14769936',
#   '-97.66280365',
#   '510',
#   'NA',
#   'US',
#   'US-TX',
#   'Elroy',
#   'no',
#   '02XS',
#   '',
#   '02XS',
#   '',
#   '',
#   ''],
#  ['325508',
#   '03AA',
#   'heliport',
#   'Trapper T Heliport',
#   '61.556055',
#   '-149.284527',
#   '159',
#   'NA',
#   'US',
#   'US-AK',
#   'Palmer',
#   'no',
#   '03AA',
#   '',
#   '03AA',
#   '',
#   '',
#   ''],
#  ['6696',
#   '03AK',
#   'seaplane_base',
#   'Joe Clouds Seaplane Base',
#   '60.72722244',
#   '-151.132782',
#   '150',
#   'NA',
#   'US',
#   'US-AK',
#   'Kenai',
#   'no',
#   '03AK',
#   '',
#   '03AK',
#   '',
#   '',
#   ''],
#  ['6697',
#   '03AL',
#   'heliport',
#   'Highland Medical Center Heliport',
#   '34.662604',
#   '-86.046774',
#   '628',
#   'NA',
#   'US',
#   'US-AL',
#   'Scottsboro',
#   'no',
#   '03AL',
#   '',
#   '03AL',
#   '',
#   '',
#   'Jackson County Hospital Heliport'],
#  ['6698',
#   '03AR',
#   'heliport',
#   'Hscmh Heliport',
#   '34.35760117',
#   '-92.78849792',
#   '350',
#   'NA',
#   'US',
#   'US-AR',
#   'Malvern',
#   'no',
#   '03AR',
#   '',
#   '03AR',
#   '',
#   '',
#   ''],
#  ['6699',
#   '03AZ',
#   'small_airport',
#   'Thompson International Aviation Airport',
#   '31.4333992',
#   '-110.0839996',
#   '4275',
#   'NA',
#   'US',
#   'US-AZ',
#   'Hereford',
#   'no',
#   '03AZ',
#   '',
#   '03AZ',
#   '',
#   '',
#   ''],
#  ['6700',
#   '03CA',
#   'heliport',
#   'Grossmont Hospital Heliport',
#   '32.779484',
#   '-117.006952',
#   '634',
#   'NA',
#   'US',
#   'US-CA',
#   'La Mesa',
#   'no',
#   '03CA',
#   '',
#   '03CA',
#   '',
#   '',
#   ''],
#  ['6701',
#   '03CO',
#   'small_airport',
#   'Kugel-Strong Airport',
#   '40.21250153',
#   '-104.7440033',
#   '4950',
#   'NA',
#   'US',
#   'US-CO',
#   'Platteville',
#   'no',
#   '03CO',
#   '',
#   '03CO',
#   '',
#   '',
#   ''],
#  ['6702',
#   '03FA',
#   'small_airport',
#   'Lake Persimmon Airstrip',
#   '27.35309982',
#   '-81.40809631',
#   '70',
#   'NA',
#   'US',
#   'US-FL',
#   'Lake Placid',
#   'no',
#   '03FA',
#   '',
#   '03FA',
#   '',
#   '',
#   ''],
#  ['6703',
#   '03FD',
#   'closed',
#   'Tharpe Airport',
#   '30.8288',
#   '-85.731003',
#   '115',
#   'NA',
#   'US',
#   'US-FL',
#   'Bonifay',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '03FD'],
#  ['6704',
#   '03FL',
#   'heliport',
#   'Ranger Heliport',
#   '26.68370056',
#   '-80.18730164',
#   '20',
#   'NA',
#   'US',
#   'US-FL',
#   'West Palm Beach',
#   'no',
#   '03FL',
#   '',
#   '03FL',
#   '',
#   '',
#   ''],
#  ['322717',
#   '03GA',
#   'small_airport',
#   'HIA Airport',
#   '32.5623056',
#   '-81.8576944',
#   '238',
#   'NA',
#   'US',
#   'US-IN',
#   'Statesboro',
#   'no',
#   '03GA',
#   '',
#   '03GA',
#   '',
#   '',
#   ''],
#  ['6705',
#   '03I',
#   'closed',
#   'Clarks Dream Strip',
#   '39.644199',
#   '-83.018204',
#   '680',
#   'NA',
#   'US',
#   'US-OH',
#   'Circleville',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '03I'],
#  ['6706',
#   '03IA',
#   'small_airport',
#   'East Field',
#   '41.58190155',
#   '-92.46130371',
#   '954',
#   'NA',
#   'US',
#   'US-IA',
#   'Montezuma',
#   'no',
#   '03IA',
#   '',
#   '03IA',
#   '',
#   '',
#   ''],
#  ['6707',
#   '03ID',
#   'small_airport',
#   'Flying Y Ranch Airport',
#   '44.79430008',
#   '-116.5329971',
#   '3180',
#   'NA',
#   'US',
#   'US-ID',
#   'Council',
#   'no',
#   '03ID',
#   '',
#   '03ID',
#   '',
#   '',
#   ''],
#  ['6708',
#   '03II',
#   'small_airport',
#   'Davis Field Ultralightport',
#   '37.9620018',
#   '-87.77890015',
#   '465',
#   'NA',
#   'US',
#   'US-IN',
#   'Mount Vernon',
#   'no',
#   '03II',
#   '',
#   '03II',
#   '',
#   '',
#   ''],
#  ['6709',
#   '03IL',
#   'small_airport',
#   'Wix Airport',
#   '41.40230179',
#   '-87.8167038',
#   '750',
#   'NA',
#   'US',
#   'US-IL',
#   'Monee',
#   'no',
#   '03IL',
#   '',
#   '03IL',
#   '',
#   '',
#   ''],
#  ['6710',
#   '03IN',
#   'small_airport',
#   'Heinzman Airport',
#   '40.18000031',
#   '-86.01249695',
#   '850',
#   'NA',
#   'US',
#   'US-IN',
#   'Arcadia',
#   'no',
#   '03IN',
#   '',
#   '03IN',
#   '',
#   '',
#   ''],
#  ['6711',
#   '03IS',
#   'heliport',
#   "OSF St Anthony's Health Center Heliport",
#   '38.904999',
#   '-90.173401',
#   '580',
#   'NA',
#   'US',
#   'US-IL',
#   'Alton',
#   'no',
#   '03IS',
#   '',
#   '03IS',
#   '',
#   '',
#   "St Anthony's Hospital"],
#  ['6712',
#   '03KS',
#   'heliport',
#   'Valley Grain Heliport',
#   '39.86470032',
#   '-95.26409912',
#   '1160',
#   'NA',
#   'US',
#   'US-KS',
#   'Highland',
#   'no',
#   '03KS',
#   '',
#   '03KS',
#   '',
#   '',
#   ''],
#  ['6713',
#   '03KY',
#   'small_airport',
#   'Flying H Farms Airport',
#   '37.79169846',
#   '-87.54139709',
#   '385',
#   'NA',
#   'US',
#   'US-KY',
#   'Henderson',
#   'no',
#   '03KY',
#   '',
#   '03KY',
#   '',
#   '',
#   ''],
#  ['6714',
#   '03LA',
#   'heliport',
#   'Damien Heliport',
#   '30.19960022',
#   '-91.12789917',
#   '25',
#   'NA',
#   'US',
#   'US-LA',
#   'Carville',
#   'no',
#   '03LA',
#   '',
#   '03LA',
#   '',
#   '',
#   ''],
#  ['6715',
#   '03LS',
#   'heliport',
#   'Fmc Nr 1 Heliport',
#   '32.1590004',
#   '-91.70800018',
#   '79',
#   'NA',
#   'US',
#   'US-LA',
#   'Winnsboro',
#   'no',
#   '03LS',
#   '',
#   '03LS',
#   '',
#   '',
#   ''],
#  ['6716',
#   '03M',
#   'seaplane_base',
#   'Lakeside Marina Seaplane Base',
#   '44.32089996',
#   '-69.88950348',
#   '165',
#   'NA',
#   'US',
#   'US-ME',
#   'East Winthrop',
#   'no',
#   '03M',
#   '',
#   '03M',
#   '',
#   '',
#   ''],
#  ['6717',
#   '03MA',
#   'small_airport',
#   'Hadley Airport',
#   '42.39310074',
#   '-72.55200195',
#   '150',
#   'NA',
#   'US',
#   'US-MA',
#   'Hadley',
#   'no',
#   '03MA',
#   '',
#   '03MA',
#   '',
#   '',
#   ''],
#  ['6718',
#   '03MD',
#   'heliport',
#   'Upper Chesapeake Medical Center Heliport',
#   '39.52249908',
#   '-76.3266983',
#   '302',
#   'NA',
#   'US',
#   'US-MD',
#   'Bel Air',
#   'no',
#   '03MD',
#   '',
#   '03MD',
#   '',
#   '',
#   ''],
#  ['6719',
#   '03ME',
#   'small_airport',
#   'Maple Ridge Airport',
#   '44.08420181',
#   '-70.62729645',
#   '556',
#   'NA',
#   'US',
#   'US-ME',
#   'Harrison',
#   'no',
#   '03ME',
#   '',
#   '03ME',
#   '',
#   '',
#   ''],
#  ['6720',
#   '03MI',
#   'heliport',
#   'Harold Miller Heliport',
#   '43.55089951',
#   '-83.86219788',
#   '585',
#   'NA',
#   'US',
#   'US-MI',
#   'Bay City',
#   'no',
#   '03MI',
#   '',
#   '03MI',
#   '',
#   '',
#   ''],
#  ['6721',
#   '03MN',
#   'small_airport',
#   'Nauerth Land Ranch Airport',
#   '43.62519836',
#   '-95.22470093',
#   '1435',
#   'NA',
#   'US',
#   'US-MN',
#   'Lakefield',
#   'no',
#   '03MN',
#   '',
#   '03MN',
#   '',
#   '',
#   ''],
#  ['6722',
#   '03MO',
#   'closed',
#   'Cahoochie Airport',
#   '37.884499',
#   '-93.131599',
#   '1010',
#   'NA',
#   'US',
#   'US-MO',
#   'Urbana',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '03MO'],
#  ['6723',
#   '03MS',
#   'heliport',
#   'Vicksburg Medical Center Heliport',
#   '32.31880188',
#   '-90.8832016',
#   '110',
#   'NA',
#   'US',
#   'US-MS',
#   'Vicksburg',
#   'no',
#   '03MS',
#   '',
#   '03MS',
#   '',
#   '',
#   ''],
#  ['6724',
#   '03MT',
#   'small_airport',
#   'Cascade Field',
#   '47.267327',
#   '-111.71748',
#   '3580',
#   'NA',
#   'US',
#   'US-MT',
#   'Cascade',
#   'no',
#   '3MT7',
#   '',
#   '3MT7',
#   '',
#   '',
#   '03MT'],
#  ['6725',
#   '03MU',
#   'small_airport',
#   'Mc Donnell Airport',
#   '38.49250031',
#   '-94.41249847',
#   '874',
#   'NA',
#   'US',
#   'US-MO',
#   'Archie',
#   'no',
#   '03MU',
#   '',
#   '03MU',
#   '',
#   '',
#   ''],
#  ['4650',
#   '03N',
#   'small_airport',
#   'Utirik Airport',
#   '11.222',
#   '169.852005',
#   '4',
#   'OC',
#   'MH',
#   'MH-UTI',
#   'Utirik Island',
#   'yes',
#   'K03N',
#   'UTK',
#   '03N',
#   '',
#   'https://en.wikipedia.org/wiki/Utirik_Airport',
#   ''],
#  ['6726',
#   '03NC',
#   'small_airport',
#   'Pilots Ridge Airport',
#   '34.10430145',
#   '-77.90419769',
#   '35',
#   'NA',
#   'US',
#   'US-NC',
#   'Carolina Beach',
#   'no',
#   '03NC',
#   '',
#   '03NC',
#   '',
#   '',
#   ''],
#  ['6727',
#   '03ND',
#   'small_airport',
#   'Olafson Brothers Airport',
#   '48.62639999',
#   '-97.82900238',
#   '1045',
#   'NA',
#   'US',
#   'US-ND',
#   'Edinburg',
#   'no',
#   '03ND',
#   '',
#   '03ND',
#   '',
#   '',
#   ''],
#  ['6728',
#   '03NE',
#   'small_airport',
#   'Hyde Ranch Airport',
#   '41.54639816',
#   '-99.33119965',
#   '2430',
#   'NA',
#   'US',
#   'US-NE',
#   'Comstock',
#   'no',
#   '03NE',
#   '',
#   '03NE',
#   '',
#   '',
#   ''],
#  ['6729',
#   '03NH',
#   'heliport',
#   'Lorden Heliport',
#   '42.81539917',
#   '-71.12439728',
#   '400',
#   'NA',
#   'US',
#   'US-NH',
#   'Milford',
#   'no',
#   '03NH',
#   '',
#   '03NH',
#   '',
#   '',
#   ''],
#  ['6730',
#   '03NJ',
#   'heliport',
#   'At&T Heliport',
#   '40.66870117',
#   '-74.41069794',
#   '360',
#   'NA',
#   'US',
#   'US-NJ',
#   'Berkeley Heights',
#   'no',
#   '03NJ',
#   '',
#   '03NJ',
#   '',
#   '',
#   ''],
#  ['6731',
#   '03NV',
#   'small_airport',
#   'Llama Ranch Airport',
#   '40.58440018',
#   '-115.2979965',
#   '6120',
#   'NA',
#   'US',
#   'US-NV',
#   'Ruby Valley',
#   'no',
#   '03NV',
#   '',
#   '03NV',
#   '',
#   '',
#   ''],
#  ['6732',
#   '03NY',
#   'small_airport',
#   'Talmage Field',
#   '40.95840073',
#   '-72.71679688',
#   '95',
#   'NA',
#   'US',
#   'US-NY',
#   'Riverhead',
#   'no',
#   '03NY',
#   '',
#   '03NY',
#   '',
#   '',
#   ''],
#  ['6733',
#   '03OH',
#   'small_airport',
#   'Gibbs Field',
#   '41.41839981',
#   '-83.01740265',
#   '580',
#   'NA',
#   'US',
#   'US-OH',
#   'Fremont',
#   'no',
#   '03OH',
#   '',
#   '03OH',
#   '',
#   '',
#   ''],
#  ['6734',
#   '03OI',
#   'heliport',
#   'Marymount Hospital Heliport',
#   '41.42089844',
#   '-81.59980011',
#   '890',
#   'NA',
#   'US',
#   'US-OH',
#   'Garfield Heights',
#   'no',
#   '03OI',
#   '',
#   '03OI',
#   '',
#   '',
#   ''],
#  ['6735',
#   '03OK',
#   'small_airport',
#   'Sahoma Lake Airport',
#   '36.04119873',
#   '-96.16139984',
#   '890',
#   'NA',
#   'US',
#   'US-OK',
#   'Sapulpa',
#   'no',
#   '03OK',
#   '',
#   '03OK',
#   '',
#   '',
#   ''],
#  ['6736',
#   '03OR',
#   'small_airport',
#   'Powwatka Ridge Airport',
#   '45.85540009',
#   '-117.4840012',
#   '3340',
#   'NA',
#   'US',
#   'US-OR',
# ...
#   'small_airport',
#   'Roosterville Airport',
#   '39.29109955',
#   '-94.44219971',
#   '1004',
#   'NA',
#   'US',
#   'US-MO',
#   'Liberty',
#   'no',
#   '0N0',
#   '',
#   '0N0',
#   '',
#   '',
#   ''],
#  ['7380',
#   '0N4',
#   'small_airport',
#   'Chandelle Estates Airport',
#   '39.20230103',
#   '-75.48549652',
#   '22',
#   'NA',
#   'US',
#   'US-DE',
#   'Dover',
#   'no',
#   '0N4',
#   '',
#   '0N4',
#   '',
#   '',
#   ''],
#  ['7381',
#   '0N5',
#   'heliport',
#   'Deldot Helistop',
#   '39.14960098',
#   '-75.50489807',
#   '30',
#   'NA',
#   'US',
#   'US-DE',
#   'Dover',
#   'no',
#   '0N5',
#   '',
#   '0N5',
#   '',
#   '',
#   ''],
#  ['7382',
#   '0N6',
#   'small_airport',
#   'Albanna Aviation Airport',
#   '39.012602',
#   '-75.533501',
#   '50',
#   'NA',
#   'US',
#   'US-DE',
#   'Felton',
#   'no',
#   '',
#   '',
#   '0N6',
#   '',
#   'https://web.archive.org/web/20170306030610/https://en.wikipedia.org/wiki/Henderson_Aviation_Airport',
#   'Henderson Aviation'],
#  ['7383',
#   '0NA1',
#   'small_airport',
#   'Goerger Airport',
#   '46.24549866',
#   '-97.03759766',
#   '1045',
#   'NA',
#   'US',
#   'US-ND',
#   'Barney',
#   'no',
#   '0NA1',
#   '',
#   '0NA1',
#   '',
#   '',
#   ''],
#  ['7384',
#   '0NA5',
#   'small_airport',
#   'Sorlie Airport',
#   '48.00109863',
#   '-99.56289673',
#   '1580',
#   'NA',
#   'US',
#   'US-ND',
#   'Maddock',
#   'no',
#   '0NA5',
#   '',
#   '0NA5',
#   '',
#   '',
#   ''],
#  ['7385',
#   '0NA9',
#   'small_airport',
#   "Boyd's Turf Airport",
#   '46.75',
#   '-103.8010025',
#   '2750',
#   'NA',
#   'US',
#   'US-ND',
#   'Golva',
#   'no',
#   '0NA9',
#   '',
#   '0NA9',
#   '',
#   '',
#   ''],
#  ['7386',
#   '0NC0',
#   'heliport',
#   'Wayne Memorial Hospital Inc. Heliport',
#   '35.3987999',
#   '-77.9496994',
#   '106',
#   'NA',
#   'US',
#   'US-NC',
#   'Goldsboro',
#   'no',
#   '0NC0',
#   '',
#   '0NC0',
#   '',
#   '',
#   ''],
#  ['7387',
#   '0NC1',
#   'small_airport',
#   'Bearwallow Farm Airport',
#   '35.45709991',
#   '-82.37539673',
#   '3608',
#   'NA',
#   'US',
#   'US-NC',
#   'Hendersonville',
#   'no',
#   '0NC1',
#   '',
#   '0NC1',
#   '',
#   '',
#   ''],
#  ['7388',
#   '0NC2',
#   'heliport',
#   'Moore Regional Hospital Heliport',
#   '35.20489883',
#   '-79.45670319',
#   '460',
#   'NA',
#   'US',
#   'US-NC',
#   'Pinehurst',
#   'no',
#   '0NC2',
#   '',
#   '0NC2',
#   '',
#   '',
#   ''],
#  ['7389',
#   '0NC3',
#   'heliport',
#   'Washington County Hospital Heliport',
#   '35.87519836',
#   '-76.6996994',
#   '19',
#   'NA',
#   'US',
#   'US-NC',
#   'Plymouth',
#   'no',
#   '0NC3',
#   '',
#   '0NC3',
#   '',
#   '',
#   ''],
#  ['7390',
#   '0NC4',
#   'heliport',
#   'Wake Medical Center Heliport',
#   '35.78680038',
#   '-78.58580017',
#   '245',
#   'NA',
#   'US',
#   'US-NC',
#   'Raleigh',
#   'no',
#   '0NC4',
#   '',
#   '0NC4',
#   '',
#   '',
#   ''],
#  ['7391',
#   '0NC5',
#   'heliport',
#   'Nash General Hospital Heliport',
#   '35.91889954',
#   '-77.78919983',
#   '156',
#   'NA',
#   'US',
#   'US-NC',
#   'Rocky Mount',
#   'no',
#   '0NC5',
#   '',
#   '0NC5',
#   '',
#   '',
#   ''],
#  ['7392',
#   '0NC6',
#   'heliport',
#   'Our Community Hospital Heliport',
#   '36.13130188',
#   '-77.41889954',
#   '113',
#   'NA',
#   'US',
#   'US-NC',
#   'Scotland Neck',
#   'no',
#   '0NC6',
#   '',
#   '0NC6',
#   '',
#   '',
#   ''],
#  ['7393',
#   '0NC7',
#   'small_airport',
#   'Lindsay Airport',
#   '36.35720062',
#   '-79.99749756',
#   '700',
#   'NA',
#   'US',
#   'US-NC',
#   'Madison',
#   'no',
#   '0NC7',
#   '',
#   '0NC7',
#   '',
#   '',
#   ''],
#  ['7394',
#   '0NC8',
#   'small_airport',
#   'Flying S Ranch Airport',
#   '35.755699',
#   '-80.735298',
#   '830',
#   'NA',
#   'US',
#   'US-NC',
#   'Cleveland',
#   'no',
#   '0NC8',
#   '',
#   '0NC8',
#   '',
#   '',
#   'Double Creek Ranch'],
#  ['7395',
#   '0NC9',
#   'heliport',
#   'Maria Parham Health DLP Affiliate Heliport',
#   '36.3307',
#   '-78.449699',
#   '465',
#   'NA',
#   'US',
#   'US-NC',
#   'Henderson',
#   'no',
#   '0NC9',
#   '',
#   '0NC9',
#   '',
#   '',
#   'Maria Parham Hospital'],
#  ['7396',
#   '0ND0',
#   'small_airport',
#   'Gilbertson Field',
#   '47.92919922',
#   '-99.40039825',
#   '1550',
#   'NA',
#   'US',
#   'US-ND',
#   'Flora',
#   'no',
#   '0ND0',
#   '',
#   '0ND0',
#   '',
#   '',
#   ''],
#  ['7397',
#   '0ND6',
#   'small_airport',
#   'Schumacher Strip',
#   '46.05500031',
#   '-99.917099',
#   '2020',
#   'NA',
#   'US',
#   'US-ND',
#   'Hague',
#   'no',
#   '0ND6',
#   '',
#   '0ND6',
#   '',
#   '',
#   ''],
#  ['7398',
#   '0ND7',
#   'small_airport',
#   'Saville Private Airport',
#   '46.46530151',
#   '-100.1050034',
#   '1961',
#   'NA',
#   'US',
#   'US-ND',
#   'Hazelton',
#   'no',
#   '0ND7',
#   '',
#   '0ND7',
#   '',
#   '',
#   ''],
#  ['7399',
#   '0NE0',
#   'small_airport',
#   'Merrihew Airport',
#   '41.84999847',
#   '-101.9499969',
#   '3815',
#   'NA',
#   'US',
#   'US-NE',
#   'Ashby',
#   'no',
#   '0NE0',
#   '',
#   '0NE0',
#   '',
#   '',
#   ''],
#  ['7400',
#   '0NE1',
#   'small_airport',
#   'Runner Landing Area Airport',
#   '42.40719986',
#   '-101.9319992',
#   '3760',
#   'NA',
#   'US',
#   'US-NE',
#   'Ashby',
#   'no',
#   '0NE1',
#   '',
#   '0NE1',
#   '',
#   '',
#   ''],
#  ['7401',
#   '0NE2',
#   'small_airport',
#   'Merry Airport',
#   '41.86660004',
#   '-101.9169998',
#   '3791',
#   'NA',
#   'US',
#   'US-NE',
#   'Ashby',
#   'no',
#   '0NE2',
#   '',
#   '0NE2',
#   '',
#   '',
#   ''],
#  ['7402',
#   '0NE3',
#   'heliport',
#   'Syracuse Hospital Heliport',
#   '40.66719818',
#   '-96.18640137',
#   '1120',
#   'NA',
#   'US',
#   'US-NE',
#   'Syracuse',
#   'no',
#   '0NE3',
#   '',
#   '0NE3',
#   '',
#   '',
#   ''],
#  ['7403',
#   '0NE4',
#   'heliport',
#   'Franklin County Memorial Hospital Heliport',
#   '40.09719849',
#   '-98.95040131',
#   '1950',
#   'NA',
#   'US',
#   'US-NE',
#   'Franklin',
#   'no',
#   '0NE4',
#   '',
#   '0NE4',
#   '',
#   '',
#   ''],
#  ['7404',
#   '0NE5',
#   'small_airport',
#   'Newman Airport',
#   '41.02109909',
#   '-102.0179977',
#   '3525',
#   'NA',
#   'US',
#   'US-NE',
#   'Big Springs',
#   'no',
#   '0NE5',
#   '',
#   '0NE5',
#   '',
#   '',
#   ''],
#  ['7405',
#   '0NE6',
#   'small_airport',
#   'Frager Field',
#   '40.43330002',
#   '-98.07060242',
#   '1765',
#   'NA',
#   'US',
#   'US-NE',
#   'Fairfield',
#   'no',
#   '0NE6',
#   '',
#   '0NE6',
#   '',
#   '',
#   ''],
#  ['324652',
#   '0NH7',
#   'heliport',
#   'Leinsing Heliport',
#   '43.151831',
#   '-70.846902',
#   '10',
#   'NA',
#   'US',
#   'US-NH',
#   'Dover',
#   'no',
#   '0NH7',
#   '',
#   '0NH7',
#   '',
#   '',
#   '2ME7'],
#  ['7406',
#   '0NJ0',
#   'heliport',
#   'Atlantic City Medical Center Heliport',
#   '39.35897025',
#   '-74.4346717',
#   '82',
#   'NA',
#   'US',
#   'US-NJ',
#   'Atlantic City',
#   'no',
#   '0NJ0',
#   '',
#   '0NJ0',
#   '',
#   '',
#   ''],
#  ['7407',
#   '0NJ1',
#   'heliport',
#   'Berkeley Township Police Heliport',
#   '39.90729904',
#   '-74.23490143',
#   '54',
#   'NA',
#   'US',
#   'US-NJ',
#   'Bayville',
#   'no',
#   '0NJ1',
#   '',
#   '0NJ1',
#   '',
#   '',
#   ''],
#  ['7408',
#   '0NJ2',
#   'heliport',
#   'Ballymere Heliport',
#   '40.75289917',
#   '-74.43990326',
#   '280',
#   'NA',
#   'US',
#   'US-NJ',
#   'Morristown',
#   'no',
#   '0NJ2',
#   '',
#   '0NJ2',
#   '',
#   '',
#   ''],
#  ['7409',
#   '0NJ3',
#   'heliport',
#   'Mount Holly Heliport',
#   '39.96680069',
#   '-74.79959869',
#   '45',
#   'NA',
#   'US',
#   'US-NJ',
#   'Mount Holly',
#   'no',
#   '0NJ3',
#   '',
#   '0NJ3',
#   '',
#   '',
#   ''],
#  ['7410',
#   '0NJ4',
#   'heliport',
#   'Weichert Headquarters Heliport',
#   '40.94070053',
#   '-74.46150208',
#   '103',
#   'NA',
#   'US',
#   'US-NJ',
#   'Morris Plains',
#   'no',
#   '0NJ4',
#   '',
#   '0NJ4',
#   '',
#   '',
#   ''],
#  ['7411',
#   '0NJ5',
#   'small_airport',
#   'Fla-Net Airport',
#   '40.88589859',
#   '-74.70570374',
#   '1040',
#   'NA',
#   'US',
#   'US-NJ',
#   'Netcong',
#   'no',
#   '0NJ5',
#   '',
#   '0NJ5',
#   '',
#   '',
#   ''],
#  ['7412',
#   '0NJ6',
#   'small_airport',
#   'Dix Field',
#   '39.31679916',
#   '-74.63289642',
#   '8',
#   'NA',
#   'US',
#   'US-NJ',
#   'Linwood',
#   'no',
#   '0NJ6',
#   '',
#   '0NJ6',
#   '',
#   '',
#   ''],
#  ['7413',
#   '0NJ7',
#   'heliport',
#   'Essex Generating Station Heliport',
#   '40.7378006',
#   '-74.11889648',
#   '8',
#   'NA',
#   'US',
#   'US-NJ',
#   'Newark',
#   'no',
#   '0NJ7',
#   '',
#   '0NJ7',
#   '',
#   '',
#   ''],
#  ['7414',
#   '0NJ8',
#   'heliport',
#   'Port Newark Helistop',
#   '40.70230103',
#   '-74.15070343',
#   '10',
#   'NA',
#   'US',
#   'US-NJ',
#   'Newark',
#   'no',
#   '0NJ8',
#   '',
#   '0NJ8',
#   '',
#   '',
#   ''],
#  ['7415',
#   '0NJ9',
#   'heliport',
#   'Jersey Tpke New Brunswick Helistop',
#   '40.47729874',
#   '-74.40789795',
#   '70',
#   'NA',
#   'US',
#   'US-NJ',
#   'New Brunswick',
#   'no',
#   '0NJ9',
#   '',
#   '0NJ9',
#   '',
#   '',
#   ''],
#  ['7416',
#   '0NK0',
#   'small_airport',
#   'Berdick Field',
#   '42.33399963',
#   '-78.79090118',
#   '1690',
#   'NA',
#   'US',
#   'US-NY',
#   'Cattaraugus',
#   'no',
#   '0NK0',
#   '',
#   '0NK0',
#   '',
#   '',
#   ''],
#  ['7417',
#   '0NK1',
#   'small_airport',
#   'Spring Brook Airport',
#   '43.36169815',
#   '-76.22019958',
#   '450',
#   'NA',
#   'US',
#   'US-NY',
#   'Central Square',
#   'no',
#   '0NK1',
#   '',
#   '0NK1',
#   '',
#   '',
#   ''],
#  ['7418',
#   '0NK2',
#   'small_airport',
#   'Westwind Farm Airport',
#   '42.98339844',
#   '-74.0161972',
#   '800',
#   'NA',
#   'US',
#   'US-NY',
#   'Charlton',
#   'no',
#   '0NK2',
#   '',
#   '0NK2',
#   '',
#   '',
#   ''],
#  ['7419',
#   '0NK3',
#   'small_airport',
#   'Seven Gullies Airport',
#   '42.69589996',
#   '-77.79219818',
#   '600',
#   'NA',
#   'US',
#   'US-NY',
#   'Groveland',
#   'no',
#   '0NK3',
#   '',
#   '0NK3',
#   '',
#   '',
#   ''],
#  ['7420',
#   '0NK4',
#   'heliport',
#   'Medical Center Heliport',
#   '40.72589874',
#   '-73.55370331',
#   '80',
#   'NA',
#   'US',
#   'US-NY',
#   'Hempstead',
#   'no',
#   '0NK4',
#   '',
#   '0NK4',
#   '',
#   '',
#   ''],
#  ['7421',
#   '0NK5',
#   'closed',
#   'Mid-Hudson Helicopter Service Heliport',
#   '41.606201',
#   '-73.827599',
#   '270',
#   'NA',
#   'US',
#   'US-NY',
#   'Hopewell Junction',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0NK5'],
#  ['7422',
#   '0NK6',
#   'small_airport',
#   'Lapeer Flyer Airport',
#   '42.43840027',
#   '-76.08879852',
#   '1280',
#   'NA',
#   'US',
#   'US-NY',
#   'Marathon',
#   'no',
#   '0NK6',
#   '',
#   '0NK6',
#   '',
#   '',
#   ''],
#  ['7423',
#   '0NK7',
#   'heliport',
#   'Ibm King St Heliport',
#   '41.10250092',
#   '-73.72609711',
#   '470',
#   'NA',
#   'US',
#   'US-NY',
#   'Armonk',
#   'no',
#   '0NK7',
#   '',
#   '0NK7',
#   '',
#   '',
#   ''],
#  ['7424',
#   '0NK8',
#   'small_airport',
#   'Rocky Reef Farm Airport',
#   '41.92089844',
#   '-73.67040253',
#   '450',
#   'NA',
#   'US',
#   'US-NY',
#   'Attlebury',
#   'no',
#   '0NK8',
#   '',
#   '0NK8',
#   '',
#   '',
#   ''],
#  ['7425',
#   '0NK9',
#   'small_airport',
#   'Lakeview Airport',
#   '43.01029968',
#   '-75.82689667',
#   '1050',
#   'NA',
#   'US',
#   'US-NY',
#   'Chittenango',
#   'no',
#   '0NK9',
#   '',
#   '0NK9',
#   '',
#   '',
#   ''],
#  ['7426',
#   '0NM0',
#   'small_airport',
#   'Columbus Municipal Airport',
#   '31.82369995',
#   '-107.6269989',
#   '4024',
#   'NA',
#   'US',
#   'US-NM',
#   'Columbus',
#   'no',
#   '0NM0',
#   '',
#   '0NM0',
#   '',
#   '',
#   ''],
#  ['7427',
#   '0NM7',
#   'small_airport',
#   'Negrito Airstrip',
#   '33.52090073',
#   '-108.5429993',
#   '8143',
#   'NA',
#   'US',
#   'US-NM',
#   'Reserve',
#   'no',
#   '0NM7',
#   '',
#   '0NM7',
#   '',
#   '',
#   ''],
#  ['7428',
#   '0NV1',
#   'heliport',
#   'Summerlin Medical Center Heliport',
#   '36.1935997',
#   '-115.3010025',
#   '2745',
#   'NA',
#   'US',
#   'US-NV',
#   'Las Vegas',
#   'no',
#   '0NV1',
#   '',
#   '0NV1',
#   '',
#   '',
#   ''],
#  ['7429',
#   '0NY0',
#   'small_airport',
#   'Bennetts Airport',
#   '43.70009995',
#   '-73.98290253',
#   '1040',
#   'NA',
#   'US',
#   'US-NY',
#   'North Creek',
#   'no',
#   '0NY0',
#   '',
#   '0NY0',
#   '',
#   '',
#   ''],
#  ['7430',
#   '0NY1',
#   'small_airport',
#   'Russell Field',
#   '43.1391983',
#   '-73.65319824',
#   '260',
#   'NA',
#   'US',
#   'US-NY',
#   'Northumberland',
#   'no',
#   '0NY1',
#   '',
#   '0NY1',
#   '',
#   '',
#   ''],
#  ['7431',
#   '0NY3',
#   'small_airport',
#   'Kermizian Airport',
#   '43.31399918',
#   '-74.93209839',
#   '1440',
#   'NA',
#   'US',
#   'US-NY',
#   'Ohio',
#   'no',
#   '0NY3',
#   '',
#   '0NY3',
#   '',
#   '',
#   ''],
#  ['7432',
#   '0NY5',
#   'heliport',
#   'State Police Troop D Heliport',
#   '43.09420013',
#   '-75.64959717',
#   '507',
#   'NA',
#   'US',
#   'US-NY',
#   'Oneida',
#   'no',
#   '0NY5',
#   '',
#   '0NY5',
#   '',
#   '',
#   ''],
#  ['7433',
#   '0NY6',
#   'heliport',
#   'New York State Police Heliport',
#   '42.92839813',
#   '-76.6155014',
#   '600',
#   'NA',
#   'US',
#   'US-NY',
#   'Auburn',
#   'no',
#   '0NY6',
#   '',
#   '0NY6',
#   '',
#   '',
#   ''],
#  ['7434',
#   '0NY7',
#   'small_airport',
#   'Murphys Landing Strip',
#   '43.03760147',
#   '-74.18430328',
#   '940',
#   'NA',
#   'US',
#   'US-NY',
#   'Perth',
#   'no',
#   '0NY7',
#   '',
#   '0NY7',
#   '',
#   '',
#   ''],
#  ['7435',
#   '0NY8',
#   'small_airport',
#   'Wenskoski Field',
#   '42.99729919',
#   '-74.24539948',
#   '800',
#   'NA',
#   'US',
#   'US-NY',
#   'Perth',
#   'no',
#   '0NY8',
#   '',
#   '0NY8',
#   '',
#   '',
#   ''],
#  ['7436',
#   '0O0',
#   'seaplane_base',
#   'San Luis Reservoir Seaplane Base',
#   '37.05830002',
#   '-121.1259995',
#   '544',
#   'NA',
#   'US',
#   'US-CA',
#   'Los Banos',
#   'no',
#   '0O0',
#   '',
#   '0O0',
#   '',
#   '',
#   ''],
#  ['7437',
#   '0O4',
#   'small_airport',
#   'Corning Municipal Airport',
#   '39.9435997',
#   '-122.1709976',
#   '292',
#   'NA',
#   'US',
#   'US-CA',
#   'Corning',
#   'no',
#   '0O4',
#   '',
#   '0O4',
#   '',
#   'http://en.wikipedia.org/wiki/Corning_Municipal_Airport_(California)',
#   ''],
#  ['7438',
#   '0O9',
#   'small_airport',
#   'Ward Field',
#   '41.84569931',
#   '-123.9850006',
#   '356',
#   'NA',
#   'US',
#   'US-CA',
#   'Gasquet',
#   'no',
#   '0O9',
#   '',
#   '0O9',
#   '',
#   '',
#   ''],
#  ['7439',
#   '0OH1',
#   'heliport',
#   'Cirino Heliport',
#   '41.44390106',
#   '-81.32759857',
#   '1250',
#   'NA',
#   'US',
#   'US-OH',
#   'Chagrin Falls',
#   'no',
#   '0OH1',
#   '',
#   '0OH1',
#   '',
#   '',
#   ''],
#  ['7440',
#   '0OH2',
#   'closed',
#   'Jenkins Field',
#   '39.970604',
#   '-83.911598',
#   '1080',
#   'NA',
#   'US',
#   'US-OH',
#   'North Hampton',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0OH2'],
#  ['7441',
#   '0OH3',
#   'heliport',
#   "Hamilton County Sheriff's Patrol Heliport",
#   '39.27920151',
#   '-84.56469727',
#   '865',
#   'NA',
#   'US',
#   'US-OH',
#   'Forest Park',
#   'no',
#   '0OH3',
#   '',
#   '0OH3',
#   '',
#   '',
#   ''],
#  ['322182',
#   '0OH4',
#   'heliport',
#   'Upper Valley Medical Center Heliport',
#   '40.085621',
#   '-84.228562',
#   '867',
#   'NA',
#   'US',
#   'US-OH',
#   'Troy',
#   'no',
#   '0OH4',
#   '',
#   '0OH4',
#   '',
#   '',
#   ''],
#  ['7442',
#   '0OH6',
#   'small_airport',
#   'Fry Field',
#   '39.6006012',
#   '-84.0196991',
#   '775',
#   'NA',
#   'US',
#   'US-OH',
#   'Spring Valley',
#   'no',
#   '0OH6',
#   '',
#   '0OH6',
#   '',
#   '',
#   ''],
#  ['7443',
#   '0OH7',
#   'small_airport',
#   'Apple Airport',
#   '40.1432991',
#   '-84.17189789',
#   '1000',
#   'NA',
#   'US',
#   'US-OH',
#   'Piqua',
#   'no',
#   '0OH7',
#   '',
#   '0OH7',
#   '',
#   '',
#   ''],
#  ['7444',
#   '0OH8',
#   'small_airport',
#   'Fry Airport',
#   '40.18840027',
#   '-84.25610352',
#   '900',
#   'NA',
#   'US',
#   'US-OH',
#   'Piqua',
#   'no',
#   '0OH8',
#   '',
#   '0OH8',
#   '',
#   '',
#   ''],
#  ['7445',
#   '0OH9',
#   'closed',
#   'Parknavy Airport',
#   '40.0717',
#   '-83.229897',
#   '943',
#   'NA',
#   'US',
#   'US-OH',
#   'Plain City',
#   'no',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '"0OH9',
#   ' STOLport"'],
#  ['7446',
#   '0OI0',
#   'heliport',
#   'Foltz Heliport',
#   '40.73590088',
#   '-81.24680328',
#   '1012',
#   'NA',
#   'US',
#   'US-OH',
#   'East Canton',
#   'no',
#   '0OI0',
#   '',
#   '0OI0',
#   '',
#   '',
#   ''],
#  ['7447',
#   '0OI1',
#   'heliport',
#   'Autolite Heliport',
#   '41.17919922',
#   '-83.41519928',
#   '759',
#   'NA',
#   'US',
#   'US-OH',
#   'Fostoria',
#   'no',
#   '0OI1',
#   '',
#   '0OI1',
#   '',
#   '',
#   ''],
#  ['7448',
#   '0OI2',
#   'small_airport',
#   'Unger Field',
#   '39.35979843',
#   '-83.41770172',
#   '940',
#   'NA',
#   'US',
#   'US-OH',
#   'Greenfield',
#   'no',
#   '0OI2',
#   '',
#   '0OI2',
#   '',
#   '',
#   ''],
#  ['7449',
#   '0OI3',
#   'small_airport',
#   'Galloway Airport',
#   '41.38209915',
#   '-82.7161026',
#   '643',
#   'NA',
#   'US',
#   'US-OH',
#   'Sandusky',
#   'no',
#   '0OI3',
#   '',
#   '0OI3',
#   '',
#   '',
#   ''],
#  ['7450',
#   '0OI4',
#   'small_airport',
#   'Salt Box Airport',
#   '41.32426453',
#   '-81.15930939',
#   '1250',
#   'NA',
#   'US',
#   'US-OH',
#   'Hiram',
#   'no',
#   '0OI4',
#   '',
#   '0OI4',
#   '',
#   '',
#   ''],
#  ['7451',
#   '0OI6',
#   'small_airport',
#   "Victor's Landing Airport",
#   '41.83810043',
#   '-80.64369965',
#   '860',
#   'NA',
#   'US',
#   'US-OH',
#   'Kingsville',
#   'no',
#   '0OI6',
#   '',
#   '0OI6',
#   '',
#   '',
#   ''],
#  ['7452',
#   '0OI9',
#   'small_airport',
#   'Hidden Quarry Airport',
#   '38.89450073',
#   '-83.1135025',
#   '830',
#   'NA',
#   'US',
#   'US-OH',
#   'Lucasville',
#   'no',
#   '0OI9',
#   '',
#   '0OI9',
#   '',
#   '',
#   ''],
#  ['7453',
#   '0OK0',
#   'small_airport',
#   'Edmond Airport',
#   '35.6833992',
#   '-97.43360138',
#   '1169',
#   'NA',
#   'US',
#   'US-OK',
#   'Edmond',
#   'no',
#   '0OK0',
#   '',
#   '0OK0',
#   '',
#   '',
#   ''],
#  ['7454',
#   '0OK1',
#   'small_airport',
#   'Mckey Airport',
#   '34.6570015',
#   '-97.40170288',
#   '1056',
#   'NA',
#   'US',
#   'US-OK',
#   'Elmore City',
#   'no',
#   '0OK1',
#   '',
#   '0OK1',
#   '',
#   '',
#   ''],
#  ...]

# %%
 from pyspark.sql.types import *
newSchema = [StructField('year',StringType(),True),
              StructField('age',StringType(),True),
              StructField('aux_nodes',StringType(),True),
              StructField('sursta',StringType(),True)
             ]

# %%
x_df = spark.createDataFrame(s,schema=StructType(newSchema))

# %%
x_df.write.saveAsTable("haberman_table12")

# %%
spark.sql('''show tables''').show()
# Out:
# +--------+----------------+-----------+
# |database|       tableName|isTemporary|
# +--------+----------------+-----------+
# | default|haberman_table12|      false|
# +--------+----------------+-----------+

# %%
p_x = x_df.toPandas()

# %%
p_x.iloc[0:,0:]
# Out:
#     year age aux_nodes sursta
# 0     30  64         1      1
# 1     30  62         3      1
# 2     30  65         0      1
# 3     31  59         2      1
# 4     31  65         4      1
# 5     33  58        10      1
# 6     33  60         0      1
# 7     34  59         0      2
# 8     34  66         9      2
# 9     34  58        30      1
# 10    34  60         1      1
# 11    34  61        10      1
# 12    34  67         7      1
# 13    34  60         0      1
# 14    35  64        13      1
# 15    35  63         0      1
# 16    36  60         1      1
# 17    36  69         0      1
# 18    37  60         0      1
# 19    37  63         0      1
# 20    37  58         0      1
# 21    37  59         6      1
# 22    37  60        15      1
# 23    37  63         0      1
# 24    38  69        21      2
# 25    38  59         2      1
# 26    38  60         0      1
# 27    38  60         0      1
# 28    38  62         3      1
# 29    38  64         1      1
# ..   ...  ..       ...    ...
# 276   67  66         0      1
# 277   67  61         0      1
# 278   67  65         0      1
# 279   68  67         0      1
# 280   68  68         0      1
# 281   69  67         8      2
# 282   69  60         0      1
# 283   69  65         0      1
# 284   69  66         0      1
# 285   70  58         0      2
# 286   70  58         4      2
# 287   70  66        14      1
# 288   70  67         0      1
# 289   70  68         0      1
# 290   70  59         8      1
# 291   70  63         0      1
# 292   71  68         2      1
# 293   72  63         0      2
# 294   72  58         0      1
# 295   72  64         0      1
# 296   72  67         3      1
# 297   73  62         0      1
# 298   73  68         0      1
# 299   74  65         3      2
# 300   74  63         0      1
# 301   75  62         1      1
# 302   76  67         0      1
# 303   77  65         3      1
# 304   78  65         1      2
# 305   83  58         2      2
#
# [306 rows x 4 columns]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# show tables
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
from sqlalchemy import create_engine

#Input Information
host = '172.16.1.114'
port = 9870
schema = 'bdp'


#Execution
engine = create_engine(f'hive://{host}:{port}/{schema}')

# %%
engine.execute('''show tables''')
# Out:
# ---------------------------------------------------------------------------
# TTransportException                       Traceback (most recent call last)
# <ipython-input-8-817c66fad7f7> in <module>
# ----> 1 engine.execute('''show tables''')
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2176         """
#    2177
# -> 2178         connection = self._contextual_connect(close_with_result=True)
#    2179         return connection.execute(statement, *multiparams, **params)
#    2180
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# ~/anaconda3/lib/python3.7/site-packages/pyhive/hive.py in connect(*args, **kwargs)
#      92     :returns: a :py:class:`Connection` object.
#      93     """
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96
#
# ~/anaconda3/lib/python3.7/site-packages/pyhive/hive.py in __init__(self, host, port, username, database, auth, configuration, kerberos_service_name, password, thrift_transport)
#     190
#     191         try:
# --> 192             self._transport.open()
#     193             open_session_req = ttypes.TOpenSessionReq(
#     194                 client_protocol=protocol_version,
#
# ~/anaconda3/lib/python3.7/site-packages/thrift_sasl/__init__.py in open(self)
#      85     # SASL negotiation loop
#      86     while True:
# ---> 87       status, payload = self._recv_sasl_message()
#      88       if status not in (self.OK, self.COMPLETE):
#      89         raise TTransportException(type=TTransportException.NOT_OPEN,
#
# ~/anaconda3/lib/python3.7/site-packages/thrift_sasl/__init__.py in _recv_sasl_message(self)
#     106     status, length = struct.unpack(">BI", header)
#     107     if length > 0:
# --> 108       payload = self._trans.readAll(length)
#     109     else:
#     110       payload = ""
#
# ~/anaconda3/lib/python3.7/site-packages/thrift/transport/TTransport.py in readAll(self, sz)
#      58         have = 0
#      59         while (have < sz):
# ---> 60             chunk = self.read(sz - have)
#      61             chunkLen = len(chunk)
#      62             have += chunkLen
#
# ~/anaconda3/lib/python3.7/site-packages/thrift/transport/TSocket.py in read(self, sz)
#     130         if len(buff) == 0:
#     131             raise TTransportException(type=TTransportException.END_OF_FILE,
# --> 132                                       message='TSocket read 0 bytes')
#     133         return buff
#     134
#
# TTransportException: TSocket read 0 bytes

# %%
from pyhive import hive

# %%
from pyhive import hive
import pandas as pd
conn=hive.Connection(host="172.16.1.114",port=10000,username="hue")
cursor=conn.cursor()
cursor.execute('''select * haberman_table12''')
print(cursor.fetchall())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-6933cdfb8544> in <module>
#       3 conn=hive.Connection(host="172.16.1.114",port=10000,username="hue")
#       4 cursor=conn.cursor()
# ----> 5 cursor.execute('''select * haberman_table12''')
#       6 print(cursor.fetchall())
#
# ~/anaconda3/lib/python3.7/site-packages/pyhive/hive.py in execute(self, operation, parameters, **kwargs)
#     363         _logger.debug(req)
#     364         response = self._connection.client.ExecuteStatement(req)
# --> 365         _check_status(response)
#     366         self._operationHandle = response.operationHandle
#     367
#
# ~/anaconda3/lib/python3.7/site-packages/pyhive/hive.py in _check_status(response)
#     493     _logger.debug(response)
#     494     if response.status.statusCode != ttypes.TStatusCode.SUCCESS_STATUS:
# --> 495         raise OperationalError(response)
#
# OperationalError: TExecuteStatementResp(status=TStatus(statusCode=3, infoMessages=["*org.apache.hive.service.cli.HiveSQLException:Error while compiling statement: FAILED: ParseException line 1:9 extraneous input 'haberman_table12' expecting EOF near '<EOF>':28:27", 'org.apache.hive.service.cli.operation.Operation:toSQLException:Operation.java:329', 'org.apache.hive.service.cli.operation.SQLOperation:prepare:SQLOperation.java:207', 'org.apache.hive.service.cli.operation.SQLOperation:runInternal:SQLOperation.java:290', 'org.apache.hive.service.cli.operation.Operation:run:Operation.java:260', 'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatementInternal:HiveSessionImpl.java:504', 'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatement:HiveSessionImpl.java:479', 'sun.reflect.GeneratedMethodAccessor26:invoke::-1', 'sun.reflect.DelegatingMethodAccessorImpl:invoke:DelegatingMethodAccessorImpl.java:43', 'java.lang.reflect.Method:invoke:Method.java:498', 'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:78', 'org.apache.hive.service.cli.session.HiveSessionProxy:access$000:HiveSessionProxy.java:36', 'org.apache.hive.service.cli.session.HiveSessionProxy$1:run:HiveSessionProxy.java:63', 'java.security.AccessController:doPrivileged:AccessController.java:-2', 'javax.security.auth.Subject:doAs:Subject.java:422', 'org.apache.hadoop.security.UserGroupInformation:doAs:UserGroupInformation.java:1875', 'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:59', 'com.sun.proxy.$Proxy35:executeStatement::-1', 'org.apache.hive.service.cli.CLIService:executeStatement:CLIService.java:270', 'org.apache.hive.service.cli.thrift.ThriftCLIService:ExecuteStatement:ThriftCLIService.java:508', 'org.apache.hive.service.rpc.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1437', 'org.apache.hive.service.rpc.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1422', 'org.apache.thrift.ProcessFunction:process:ProcessFunction.java:39', 'org.apache.thrift.TBaseProcessor:process:TBaseProcessor.java:39', 'org.apache.hive.service.auth.TSetIpAddressProcessor:process:TSetIpAddressProcessor.java:56', 'org.apache.thrift.server.TThreadPoolServer$WorkerProcess:run:TThreadPoolServer.java:286', 'java.util.concurrent.ThreadPoolExecutor:runWorker:ThreadPoolExecutor.java:1149', 'java.util.concurrent.ThreadPoolExecutor$Worker:run:ThreadPoolExecutor.java:624', 'java.lang.Thread:run:Thread.java:748', "*org.apache.hadoop.hive.ql.parse.ParseException:line 1:9 extraneous input 'haberman_table12' expecting EOF near '<EOF>':33:6", 'org.apache.hadoop.hive.ql.parse.ParseDriver:parse:ParseDriver.java:229', 'org.apache.hadoop.hive.ql.parse.ParseUtils:parse:ParseUtils.java:75', 'org.apache.hadoop.hive.ql.parse.ParseUtils:parse:ParseUtils.java:68', 'org.apache.hadoop.hive.ql.Driver:compile:Driver.java:564', 'org.apache.hadoop.hive.ql.Driver:compileInternal:Driver.java:1425', 'org.apache.hadoop.hive.ql.Driver:compileAndRespond:Driver.java:1398', 'org.apache.hive.service.cli.operation.SQLOperation:prepare:SQLOperation.java:205'], sqlState='42000', errorCode=40000, errorMessage="Error while compiling statement: FAILED: ParseException line 1:9 extraneous input 'haberman_table12' expecting EOF near '<EOF>'"), operationHandle=None)

# %%
# %load_ext sql

# %%
# %sql hive://172.16.1.114:10000/default
# Out:
# 'Connected: @default'

# %%
# %%sql
# show tables
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
# select * from haberman_table1
# Out:
#    hive://172.16.1.114:10000/bdp
#  * hive://172.16.1.114:10000/default
# Done.
# []

# %%
# %%sql
# SHOW DATABASES;
# Out:
#    hive://172.16.1.114:10000/bdp
#  * hive://172.16.1.114:10000/default
# (pyhive.exc.OperationalError) TExecuteStatementResp(status=TStatus(statusCode=3, infoMessages=["*org.apache.hive.service.cli.HiveSQLException:Error while compiling statement: FAILED: ParseException line 1:14 extraneous input ';' expecting EOF near '<EOF>':28:27", 'org.apache.hive.service.cli.operation.Operation:toSQLException:Operation.java:329', 'org.apache.hive.service.cli.operation.SQLOperation:prepare:SQLOperation.java:207', 'org.apache.hive.service.cli.operation.SQLOperation:runInternal:SQLOperation.java:290', 'org.apache.hive.service.cli.operation.Operation:run:Operation.java:260', 'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatementInternal:HiveSessionImpl.java:504', 'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatement:HiveSessionImpl.java:479', 'sun.reflect.GeneratedMethodAccessor27:invoke::-1', 'sun.reflect.DelegatingMethodAccessorImpl:invoke:DelegatingMethodAccessorImpl.java:43', 'java.lang.reflect.Method:invoke:Method.java:498', 'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:78', 'org.apache.hive.service.cli.session.HiveSessionProxy:access$000:HiveSessionProxy.java:36', 'org.apache.hive.service.cli.session.HiveSessionProxy$1:run:HiveSessionProxy.java:63', 'java.security.AccessController:doPrivileged:AccessController.java:-2', 'javax.security.auth.Subject:doAs:Subject.java:422', 'org.apache.hadoop.security.UserGroupInformation:doAs:UserGroupInformation.java:1875', 'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:59', 'com.sun.proxy.$Proxy35:executeStatement::-1', 'org.apache.hive.service.cli.CLIService:executeStatement:CLIService.java:270', 'org.apache.hive.service.cli.thrift.ThriftCLIService:ExecuteStatement:ThriftCLIService.java:508', 'org.apache.hive.service.rpc.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1437', 'org.apache.hive.service.rpc.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1422', 'org.apache.thrift.ProcessFunction:process:ProcessFunction.java:39', 'org.apache.thrift.TBaseProcessor:process:TBaseProcessor.java:39', 'org.apache.hive.service.auth.TSetIpAddressProcessor:process:TSetIpAddressProcessor.java:56', 'org.apache.thrift.server.TThreadPoolServer$WorkerProcess:run:TThreadPoolServer.java:286', 'java.util.concurrent.ThreadPoolExecutor:runWorker:ThreadPoolExecutor.java:1149', 'java.util.concurrent.ThreadPoolExecutor$Worker:run:ThreadPoolExecutor.java:624', 'java.lang.Thread:run:Thread.java:748', "*org.apache.hadoop.hive.ql.parse.ParseException:line 1:14 extraneous input ';' expecting EOF near '<EOF>':33:6", 'org.apache.hadoop.hive.ql.parse.ParseDriver:parse:ParseDriver.java:229', 'org.apache.hadoop.hive.ql.parse.ParseUtils:parse:ParseUtils.java:75', 'org.apache.hadoop.hive.ql.parse.ParseUtils:parse:ParseUtils.java:68', 'org.apache.hadoop.hive.ql.Driver:compile:Driver.java:564', 'org.apache.hadoop.hive.ql.Driver:compileInternal:Driver.java:1425', 'org.apache.hadoop.hive.ql.Driver:compileAndRespond:Driver.java:1398', 'org.apache.hive.service.cli.operation.SQLOperation:prepare:SQLOperation.java:205'], sqlState='42000', errorCode=40000, errorMessage="Error while compiling statement: FAILED: ParseException line 1:14 extraneous input ';' expecting EOF near '<EOF>'"), operationHandle=None)
# [SQL: SHOW DATABASES;]
# (Background on this error at: http://sqlalche.me/e/e3q8)
