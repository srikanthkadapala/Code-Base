# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,5]
y=[3,8,1,9]

a= plt.plot(x,y)
a = plt.xlabel('xaxis')
a = plt.ylabel('yaxis')
a = plt.title('graph')
a.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c3ed7a65b694> in <module>
#       6 a = plt.ylabel('yaxis')
#       7 a = plt.title('graph')
# ----> 8 a.show()
#
# AttributeError: 'Text' object has no attribute 'show'
