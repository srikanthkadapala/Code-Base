# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql hive://172.16.1.114:10000/default
# Out:
# Could not connect to any of [('172.16.1.114', 10000)]
# Could not connect to any of [('172.16.1.114', 10000)]
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
pd.read_csv("hdfs://172.16.1.114:8020/user/hive/warehouse/workingDirectory/haberman.csv")

# %%
# %%!
# hadoop fs -cat hdfs:///user/hive/warehouse/workingDirectory/haberman.csv
# Out:
# ['30,64,1,1',
#  '30,62,3,1',
#  '30,65,0,1',
#  '31,59,2,1',
#  '31,65,4,1',
#  '33,58,10,1',
#  '33,60,0,1',
#  '34,59,0,2',
#  '34,66,9,2',
#  '34,58,30,1',
#  '34,60,1,1',
#  '34,61,10,1',
#  '34,67,7,1',
#  '34,60,0,1',
#  '35,64,13,1',
#  '35,63,0,1',
#  '36,60,1,1',
#  '36,69,0,1',
#  '37,60,0,1',
#  '37,63,0,1',
#  '37,58,0,1',
#  '37,59,6,1',
#  '37,60,15,1',
#  '37,63,0,1',
#  '38,69,21,2',
#  '38,59,2,1',
#  '38,60,0,1',
#  '38,60,0,1',
#  '38,62,3,1',
#  '38,64,1,1',
#  '38,66,0,1',
#  '38,66,11,1',
#  '38,60,1,1',
#  '38,67,5,1',
#  '39,66,0,2',
#  '39,63,0,1',
#  '39,67,0,1',
#  '39,58,0,1',
#  '39,59,2,1',
#  '39,63,4,1',
#  '40,58,2,1',
#  '40,58,0,1',
#  '40,65,0,1',
#  '41,60,23,2',
#  '41,64,0,2',
#  '41,67,0,2',
#  '41,58,0,1',
#  '41,59,8,1',
#  '41,59,0,1',
#  '41,64,0,1',
#  '41,69,8,1',
#  '41,65,0,1',
#  '41,65,0,1',
#  '42,69,1,2',
#  '42,59,0,2',
#  '42,58,0,1',
#  '42,60,1,1',
#  '42,59,2,1',
#  '42,61,4,1',
#  '42,62,20,1',
#  '42,65,0,1',
# ...
